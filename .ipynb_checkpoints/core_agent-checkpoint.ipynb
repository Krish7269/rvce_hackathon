# %%
my_api_key = "AIzaSyAuee6zo8bN0Oh_pMjRjtWS1oVDdoX6ygM"

import google.generativeai as genai
genai.configure(api_key=my_api_key)

# %%
import google.generativeai as genai
genai.configure(api_key=my_api_key)

for m in genai.list_models():
    print(m.name)
# Out:
# models/embedding-gecko-001
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/gemini-embedding-001
# models/aqa
# models/imagen-4.0-generate-preview-06-06
# models/imagen-4.0-ultra-generate-preview-06-06
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/gemini-2.0-flash-live-001
# models/gemini-live-2.5-flash-preview
# models/gemini-2.5-flash-live-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025

# %%
model = genai.GenerativeModel("models/gemini-2.5-flash")

# %%
from agents.report_generator import ReportGenerator
report_gen = ReportGenerator()
import os

# %%
import pandas as pd
from agents.data_cleaner import DataCleaner
from agents.visualizer import Visualizer
from agents.forecaster import Forecaster

cleaner = DataCleaner()
viz = Visualizer()
forecaster = Forecaster()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from agent.code_generator import CodeGenerator
from agent.explanation_agent import ExplanationAgent
from agent.utils import capture_output

# Dummy LLM function (replace with ADK later)
def llm(prompt):
    response = model.generate_content(prompt)
    return response.text

code_gen = CodeGenerator(llm)
exp_agent = ExplanationAgent(llm)

# %%
df = pd.read_csv("sample_data/sales.csv")
df.head()
# Out:
#   date,product,category,units_sold,unit_price,revenue,region
# 0  2024-01-03,Energy Drink,Food & Beverage,120,2....
# 1   2024-01-04,Sports Shoes,Fashion,45,50,2250,South
# 2  2024-01-05,Smart Watch,Electronics,30,120,3600...
# 3  2024-01-07,Energy Drink,Food & Beverage,180,2....
# 4  2024-01-09,Headphones,Electronics,50,80,4000,N...

# %%
def route_task(task, df):
    task = task.lower()

    if "clean" in task:
        return cleaner.clean(df)

    if "plot" in task or "visualize" in task:
        column = df.columns[1]
        path = viz.generate_plot(df, column)
        return {"plot_path": path}

    if "forecast" in task:
        column = df.columns[1]
        return forecaster.forecast_next(df, column)

    return "Task not understood."

# %%
def ask_ai(task):
    df = pd.read_csv("sample_data/sales.csv")
    result = route_task(task, df)
    return result

ask_ai("clean the data")
# Out:
# {'missing_values': {'date,product,category,units_sold,unit_price,revenue,region': 0},
#  'duplicates_removed': 0,
#  'cleaned_df':    date,product,category,units_sold,unit_price,revenue,region
#  0   2024-01-03,Energy Drink,Food & Beverage,120,2....
#  1    2024-01-04,Sports Shoes,Fashion,45,50,2250,South
#  2   2024-01-05,Smart Watch,Electronics,30,120,3600...
#  3   2024-01-07,Energy Drink,Food & Beverage,180,2....
#  4   2024-01-09,Headphones,Electronics,50,80,4000,N...
#  5         2024-01-11,T-shirt,Fashion,80,15,1200,South
#  6   2024-01-12,Energy Drink,Food & Beverage,150,2....
#  7   2024-01-14,Smart Watch,Electronics,25,120,3000...
#  8    2024-01-16,Sports Shoes,Fashion,60,50,3000,North
#  9   2024-01-18,Energy Drink,Food & Beverage,200,2....
#  10        2024-02-01,T-shirt,Fashion,95,15,1425,North
#  11  2024-02-04,Headphones,Electronics,40,80,3200,S...
#  12  2024-02-06,Smart Watch,Electronics,28,120,3360...
#  13    2024-02-09,Sports Shoes,Fashion,55,50,2750,West
#  14  2024-02-12,Energy Drink,Food & Beverage,210,2....
#  15        2024-02-15,T-shirt,Fashion,75,15,1125,South
#  16  2024-02-18,Energy Drink,Food & Beverage,180,2....
#  17  2024-02-20,Headphones,Electronics,60,80,4800,West
#  18   2024-02-22,Sports Shoes,Fashion,65,50,3250,South
#  19  2024-02-25,Smart Watch,Electronics,32,120,3840...        }

# %%
user_query = "Show me the total revenue per month with a bar chart."

# %%
generated_code = code_gen.generate(user_query, df)
print("Generated Python Code:")
print(generated_code)
# Out:
# Generated Python Code:
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Assuming df is already loaded
# # df = pd.read_csv('your_data.csv') # Example if df wasn't already available
#
# # Convert 'date' column to datetime objects
# df['date'] = pd.to_datetime(df['date'])
#
# # Extract month and year for accurate monthly grouping across different years if present
# df['year_month'] = df['date'].dt.to_period('M')
#
# # Calculate total revenue per month
# monthly_revenue = df.groupby('year_month')['revenue'].sum().reset_index()
#
# # Sort by year_month to ensure correct chronological order for plotting
# monthly_revenue = monthly_revenue.sort_values('year_month')
#
# # Convert 'year_month' back to string for better plotting labels
# monthly_revenue['year_month'] = monthly_revenue['year_month'].astype(str)
#
# # Create the bar chart
# plt.figure(figsize=(12, 6))
# sns.barplot(x='year_month', y='revenue', data=monthly_revenue, palette='viridis')
# plt.title('Total Revenue Per Month')
# plt.xlabel('Month')
# plt.ylabel('Total Revenue')
# plt.xticks(rotation=45, ha='right')
# plt.tight_layout()
#
# # Save the plot
# plt.savefig('output_plot.png')
# ```

# %%
local_env = {"df": df, "plt": plt, "sns": sns, "pd": pd, "np": np}

# Make sure plot file is deleted first
if os.path.exists("output_plot.png"):
    os.remove("output_plot.png")

exec_output = capture_output(generated_code, local_env)

print(exec_output)

print("Image Exists:", os.path.exists("output_plot.png"))
# Out:
# ERROR: invalid syntax (<string>, line 1)
# Image Exists: False

# %%
python_summary = exec_output[:500]  # short summary
print(python_summary)
# Out:
# ERROR: invalid syntax (<string>, line 1)

# %%
explanation = exp_agent.explain(user_query, python_summary)
print(explanation)
# Out:
# Here's an explanation of the findings in clear, human language:
#
# *   Unfortunately, I couldn't generate the bar chart showing total revenue per month at this time.
# *   The system encountered an error trying to understand the instructions for pulling the data. It's like the computer didn't understand what it was asked to do.
# *   This means the tool wasn't able to process the revenue figures to create the visual you requested.
# *   It's not an issue with the underlying revenue data itself, but rather with how the request was formulated for the system.
# *   I will investigate and correct this immediately, and I'll aim to provide the chart to you very shortly.

# %%
with open("reports/insight_report.txt", "w") as f:
    f.write(explanation)

plt.savefig('output_plot.png')
print("Report saved!")
# Out:
# Report saved!

# %%
summary_text = """
This is an automatically generated insight report.
It summarizes the findings from your dataset using AI.
"""

images = ["output_plot.png"]  # add your plot image names here

pdf_path = report_gen.generate_report(
    title="AI Generated Data Analysis Report",
    summary=summary_text,
    images=images
)

plt.savefig('output_plot.png')
pdf_path
# Out:
# 'report_20251201_024800.pdf'

# %%
summary_text = explanation  # from explanation_agent

# %%
def generate_full_report(user_query):
    # 1. Generate code
    code = code_gen.generate(user_query, df)
    
    # 2. Execute code
    local_env = {"df": df, "plt": plt, "sns": sns, "pd": pd, "np": np}
    exec_output = capture_output(code, local_env)
    
    # 3. Summarize results
    explanation = exp_agent.explain(user_query, exec_output)
    
    # 4. Create report with plot
    report_path = report_gen.generate_report(
        title=f"Report: {user_query}",
        summary=explanation,
        images=["output_plot.png"]
    )
    
    return explanation, report_path

summary, report_file = generate_full_report(
    "Show total revenue per month and plot it."
)

summary, report_file
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 21
#      13     report_path = report_gen.generate_report(
#      14         title=f"Report: {user_query}",
#      15         summary=explanation,
#      16         images=["output_plot.png"]
#      17     )
#      19     return explanation, report_path
# ---> 21 summary, report_file = generate_full_report(
#      22     "Show total revenue per month and plot it."
#      23 )
#      25 summary, report_file
#
# Cell In[19], line 13, in generate_full_report(user_query)
#      10 explanation = exp_agent.explain(user_query, exec_output)
#      12 # 4. Create report with plot
# ---> 13 report_path = report_gen.generate_report(
#      14     title=f"Report: {user_query}",
#      15     summary=explanation,
#      16     images=["output_plot.png"]
#      17 )
#      19 return explanation, report_path
#
# File C:\ai-analyst-hackathon\anaconda_projects\agents\report_generator.py:57, in ReportGenerator.generate_report(self, title, summary, images)
#      55 timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
#      56 filename = f"report_{timestamp}.pdf"
# ---> 57 return self.save(filename)
#
# File C:\ai-analyst-hackathon\anaconda_projects\agents\report_generator.py:45, in ReportGenerator.save(self, filename)
#      44 def save(self, filename="analysis_report.pdf"):
# ---> 45     self.pdf.output(filename)
#      46     return filename
#
# File ~\anaconda3\Lib\site-packages\fpdf\fpdf.py:1065, in FPDF.output(self, name, dest)
#    1063 #Finish document if necessary
#    1064 if(self.state<3):
# -> 1065     self.close()
#    1066 dest=dest.upper()
#    1067 if(dest==''):
#
# File ~\anaconda3\Lib\site-packages\fpdf\fpdf.py:246, in FPDF.close(self)
#     244 self._endpage()
#     245 #close document
# --> 246 self._enddoc()
#
# File ~\anaconda3\Lib\site-packages\fpdf\fpdf.py:1637, in FPDF._enddoc(self)
#    1635 self._putheader()
#    1636 self._putpages()
# -> 1637 self._putresources()
#    1638 #Info
#    1639 self._newobj()
#
# File ~\anaconda3\Lib\site-packages\fpdf\fpdf.py:1585, in FPDF._putresources(self)
#    1583 def _putresources(self):
#    1584     self._putfonts()
# -> 1585     self._putimages()
#    1586     #Resource dictionary
#    1587     self.offsets[2]=len(self.buffer)
#
# File ~\anaconda3\Lib\site-packages\fpdf\fpdf.py:1515, in FPDF._putimages(self)
#    1513 for idx,info in i:
#    1514     self._putimage(info)
# -> 1515     del info['data']
#    1516     if 'smask' in info:
#    1517         del info['smask']
#
# KeyError: 'data'
