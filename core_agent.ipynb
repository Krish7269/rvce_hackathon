# %%
# === Load environment variables ===
from dotenv import load_dotenv
import os

# Load .env file from project root
load_dotenv()

# Fetch the API key from .env
my_api_key = os.getenv("GOOGLE_API_KEY")

# Quick check (optional – remove later)
if my_api_key:
    print("API key loaded successfully.")
else:
    print("API key NOT found. Check your .env file.")

# === Configure Gemini API ===
import google.generativeai as genai
genai.configure(api_key=my_api_key)

print("Gemini configured and ready.")
# Out:
# API key loaded successfully.
# Gemini configured and ready.

# %%
model = genai.GenerativeModel("models/gemini-2.5-flash")

# %%
from agents.report_generator import ReportGenerator
report_gen = ReportGenerator()
import os

# %%
import pandas as pd
from agents.data_cleaner import DataCleaner
from agents.visualizer import Visualizer
from agents.forecaster import Forecaster

cleaner = DataCleaner()
viz = Visualizer()
forecaster = Forecaster()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from agent.code_generator import CodeGenerator
from agent.explanation_agent import ExplanationAgent
from agent.utils import capture_output

# Dummy LLM function (replace with ADK later)
def llm(prompt):
    response = model.generate_content(prompt)
    return response.text

code_gen = CodeGenerator(llm)
exp_agent = ExplanationAgent(llm)

# %%
df = pd.read_csv("sample_data/sales.csv")
df.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  03-02-2023       Bob  North       5053.97             18
# 1        1093  21-04-2023       Bob   West       4384.02             17
# 2        1015  21-09-2023     David  South       4631.23             30
# 3        1072  24-08-2023       Bob  South       2167.94             39
# 4        1061  24-03-2023   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# 1           Cash        Retail             West-Bob
# 2  Bank Transfer        Retail          South-David
# 3    Credit Card        Retail            South-Bob
# 4    Credit Card        Online         East-Charlie

# %%
def route_task(task, df):
    task = task.lower()

    if "clean" in task:
        return cleaner.clean(df)

    if "plot" in task or "visualize" in task:
        column = df.columns[1]
        path = viz.generate_plot(df, column)
        return {"plot_path": path}

    if "forecast" in task:
        column = df.columns[1]
        return forecaster.forecast_next(df, column)

    return "Task not understood."

# %%
def ensure_revenue_column(df):
    cols = df.columns.str.lower()

    # CASE 1: Already contains a revenue-like column
    for c in df.columns:
        if "revenue" in c.lower():
            df.rename(columns={c: "revenue"}, inplace=True)
            return df

    # CASE 2: Contains price & units_sold
    price_col = None
    units_col = None

    for c in df.columns:
        if "price" in c.lower():
            price_col = c
        if "unit" in c.lower() or "quantity" in c.lower():
            units_col = c

    if price_col and units_col:
        df["revenue"] = df[price_col] * df[units_col]
        return df

    # CASE 3: No revenue possible
    df["revenue"] = 0
    return df

# %%
df = ensure_revenue_column(df)

# %%
def ask_ai(task):
    df = pd.read_csv("sample_data/sales.csv")
    result = route_task(task, df)
    return result

ask_ai("clean the data")
# Out:
# {'missing_values': {'Product_ID': 0,
#   'Sale_Date': 0,
#   'Sales_Rep': 0,
#   'Region': 0,
#   'Sales_Amount': 0,
#   'Quantity_Sold': 0,
#   'Product_Category': 0,
#   'Unit_Cost': 0,
#   'Unit_Price': 0,
#   'Customer_Type': 0,
#   'Discount': 0,
#   'Payment_Method': 0,
#   'Sales_Channel': 0,
#   'Region_and_Sales_Rep': 0},
#  'duplicates_removed': 0,
#  'cleaned_df':      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
#  0          1052  03-02-2023       Bob  North       5053.97             18
#  1          1093  21-04-2023       Bob   West       4384.02             17
#  2          1015  21-09-2023     David  South       4631.23             30
#  3          1072  24-08-2023       Bob  South       2167.94             39
#  4          1061  24-03-2023   Charlie   East       3750.20             13
#  ..          ...         ...       ...    ...           ...            ...
#  995        1010  15-04-2023   Charlie  North       4733.88              4
#  996        1067  07-09-2023       Bob  North       4716.36             37
#  997        1018  27-04-2023     David  South       7629.70             17
#  998        1100  20-12-2023     David   West       1629.47             39
#  999        1086  16-08-2023     Alice   East       4923.93             48
#
#      Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
#  0          Furniture     152.75      267.22     Returning      0.09
#  1          Furniture    3816.39     4209.44     Returning      0.11
#  2               Food     261.56      371.40     Returning      0.20
#  3           Clothing    4330.03     4467.75           New      0.02
#  4        Electronics     637.37      692.71           New      0.08
#  ..               ...        ...         ...           ...       ...
#  995             Food    4943.03     5442.15     Returning      0.29
#  996         Clothing    1754.32     1856.40           New      0.21
#  997         Clothing     355.72      438.27     Returning      0.06
#  998      Electronics    3685.03     3743.39           New      0.01
#  999             Food    2632.58     2926.68     Returning      0.14
#
#      Payment_Method Sales_Channel Region_and_Sales_Rep
#  0             Cash        Online            North-Bob
#  1             Cash        Retail             West-Bob
#  2    Bank Transfer        Retail          South-David
#  3      Credit Card        Retail            South-Bob
#  4      Credit Card        Online         East-Charlie
#  ..             ...           ...                  ...
#  995           Cash        Online        North-Charlie
#  996  Bank Transfer        Retail            North-Bob
#  997  Bank Transfer        Online          South-David
#  998  Bank Transfer        Online           West-David
#  999           Cash        Online           East-Alice
#
#  [1000 rows x 14 columns]}

# %%
user_query = "Show me the total revenue per month with a bar chart."

# %%
def clean_code(llm_output):
    # remove markdown fences
    code = llm_output.replace("```python", "").replace("```", "")
    
    # keep ALL lines except pure text lines
    cleaned = []
    for line in code.split("\n"):
        if line.strip() == "":
            continue
        
        # remove conversational garbage
        if any(x in line.lower() for x in [
            "here is the code",
            "sure",
            "below is",
            "the following",
            "as requested"
        ]):
            continue
        
        cleaned.append(line)
    
    return "\n".join(cleaned)

def fix_seaborn_palette(code):
    # If LLM adds deprecated seaborn palette usage, remove palette or add legend=False
    if "sns." in code and "palette=" in code and "hue=" not in code:
        code = code.replace("palette=", "legend=False, palette_removed=")
    return code

# %%
import matplotlib.pyplot as plt

def force_png_no_alpha():
    fig = plt.gcf()
    fig.patch.set_facecolor("white")

# %%
def patch_savefig_alpha(code):
    # force PNGs to be saved in RGB mode
    if "plt.savefig" in code:
        code = code.replace(
            "plt.savefig(",
            "plt.gcf().patch.set_facecolor('white'); plt.savefig("
        )
    return code

# %%
import re

def auto_print_last_var(code):
    lines = code.strip().split("\n")
    last_var = None

    for line in reversed(lines):
        if "=" in line and not line.strip().startswith("#"):
            last_var = line.split("=")[0].strip()
            break

    if last_var and f"print({last_var})" not in code:
        code += f"\nprint({last_var})\n"

    return code

# %%
def fix_unclosed_braces(code):
    open_count = code.count("{")
    close_count = code.count("}")

    if open_count > close_count:
        code += "}" * (open_count - close_count)

    return code

# %%
# 1. Generate raw LLM output
raw_code = code_gen.generate(user_query, df)

# 2. Clean the LLM code (remove ```python, etc.)
cleaned_code = clean_code(raw_code)

# 3. Fix seaborn palette usage if necessary
generated_code = fix_seaborn_palette(cleaned_code)
# Inject forced patch before savefig
if "plt.savefig" in generated_code:
    generated_code = generated_code.replace(
        "plt.savefig(",
        "force_png_no_alpha(); plt.savefig("
    )

print("===== RAW CODE =====")
print(raw_code)
print("====================")

print("\n===== CLEANED CODE =====")
print(generated_code)
print("====================")
# Out:
# ===== RAW CODE =====
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Ensure 'Sale_Date' is a datetime object
# df['Sale_Date'] = pd.to_datetime(df['Sale_Date'])
#
# # Extract month and year for grouping
# df['Sale_Month'] = df['Sale_Date'].dt.to_period('M')
#
# # Calculate total revenue per month
# monthly_revenue = df.groupby('Sale_Month')['revenue'].sum().reset_index()
#
# # Convert Sale_Month back to string for better plotting labels if needed,
# # or sort by period directly
# monthly_revenue['Sale_Month_Str'] = monthly_revenue['Sale_Month'].astype(str)
#
# # Print the computed values
# print("Total revenue per month:")
# print(monthly_revenue[['Sale_Month_Str', 'revenue']])
#
# # Create the bar chart
# fig, ax = plt.subplots(figsize=(12, 7))
#
# ax.bar(monthly_revenue['Sale_Month_Str'], monthly_revenue['revenue'], color='skyblue')
#
# # Add labels and title
# ax.set_xlabel('Month', fontsize=12)
# ax.set_ylabel('Total Revenue', fontsize=12)
# ax.set_title('Total Revenue Per Month', fontsize=14)
#
# # Rotate x-axis labels for better readability if there are many months
# plt.xticks(rotation=45, ha='right')
#
# # Add grid for better readability
# ax.grid(axis='y', linestyle='--', alpha=0.7)
#
# # Make layout tight
# plt.tight_layout()
#
# # Save the plot
# plt.savefig("output_plot.png", format="png", dpi=200, bbox_inches="tight", facecolor="white")
# plt.close()
# ====================
#
# ===== CLEANED CODE =====
# import pandas as pd
# import matplotlib.pyplot as plt
# df['Sale_Date'] = pd.to_datetime(df['Sale_Date'])
# # Extract month and year for grouping
# df['Sale_Month'] = df['Sale_Date'].dt.to_period('M')
# # Calculate total revenue per month
# monthly_revenue = df.groupby('Sale_Month')['revenue'].sum().reset_index()
# # Convert Sale_Month back to string for better plotting labels if needed,
# # or sort by period directly
# monthly_revenue['Sale_Month_Str'] = monthly_revenue['Sale_Month'].astype(str)
# # Print the computed values
# print("Total revenue per month:")
# print(monthly_revenue[['Sale_Month_Str', 'revenue']])
# # Create the bar chart
# fig, ax = plt.subplots(figsize=(12, 7))
# ax.bar(monthly_revenue['Sale_Month_Str'], monthly_revenue['revenue'], color='skyblue')
# # Add labels and title
# ax.set_xlabel('Month', fontsize=12)
# ax.set_ylabel('Total Revenue', fontsize=12)
# ax.set_title('Total Revenue Per Month', fontsize=14)
# # Rotate x-axis labels for better readability if there are many months
# plt.xticks(rotation=45, ha='right')
# # Add grid for better readability
# ax.grid(axis='y', linestyle='--', alpha=0.7)
# # Make layout tight
# plt.tight_layout()
# # Save the plot
# force_png_no_alpha(); plt.savefig("output_plot.png", format="png", dpi=200, bbox_inches="tight", facecolor="white")
# plt.close()
# ====================

# %%
def auto_debug_code(bad_code, error):
    prompt = f"""
The following Python code produced an error:
{bad_code}

Error:
{error}

Fix the code. Only output corrected Python code.
"""
    return llm(prompt)

# %%
local_env = {"df": df, "plt": plt, "sns": sns, "pd": pd, "np": np, "force_png_no_alpha": force_png_no_alpha}

# Make sure plot file is deleted first
if os.path.exists("output_plot.png"):
    os.remove("output_plot.png")

exec_output = capture_output(generated_code, local_env)
if "ERROR" in exec_output:
    fixed = auto_debug_code(raw_code, exec_output)
    fixed = clean_code(fixed)
    exec_output = capture_output(fixed, local_env)

print(exec_output)

print("Image Exists:", os.path.exists("output_plot.png"))
# Out:
# Total revenue per month:
#    Sale_Month_Str       revenue
# 0         2023-01  1.056883e+09
# 1         2023-02  6.507573e+08
# 2         2023-03  7.610588e+08
# 3         2023-04  7.974712e+08
# 4         2023-05  7.596467e+08
# 5         2023-06  8.789984e+08
# 6         2023-07  6.874590e+08
# 7         2023-08  9.110048e+08
# 8         2023-09  5.820823e+08
# 9         2023-10  8.466485e+08
# 10        2023-11  6.896101e+08
# 11        2023-12  8.321018e+08
# 12        2024-01  3.344795e+06
#
# Image Exists: True

# %%
python_summary = exec_output[:500]  # short summary
print(python_summary)
# Out:
# Total revenue per month:
#    Sale_Month_Str       revenue
# 0         2023-01  1.056883e+09
# 1         2023-02  6.507573e+08
# 2         2023-03  7.610588e+08
# 3         2023-04  7.974712e+08
# 4         2023-05  7.596467e+08
# 5         2023-06  8.789984e+08
# 6         2023-07  6.874590e+08
# 7         2023-08  9.110048e+08
# 8         2023-09  5.820823e+08
# 9         2023-10  8.466485e+08
# 10        2023-11  6.896101e+08
# 11        2023-12  8.321018e+08
# 12        2024-01  3.344795e+06

# %%
explanation = exp_agent.explain(user_query, python_summary)
print(explanation)
# Out:
# Here are the key findings and some strategic recommendations based on our monthly revenue performance:
#
# **Revenue Performance Overview:**
#
# *   **Strong Start to 2023:** January 2023 was our strongest month by far, bringing in over 1 billion dollars in revenue. This set a high benchmark for the year.
# *   **Consistent Performance:** For most of 2023, our monthly revenue consistently hovered between 600 million and 900 million dollars, indicating a generally healthy and stable sales environment.
# *   **Fluctuating Trends:** While consistent, revenue wasn't flat. We saw natural ups and downs throughout the year, with some months performing better than others.
# *   **Mid-Year Dip:** September 2023 was our lowest revenue month for the year, totaling just over 582 million dollars. This could be a good area for further investigation.
# *   **Second Best Month:** August 2023 was a strong performer, nearing 911 million dollars, showing a good recovery after the mid-year dips.
# *   **End of Year Boost:** While not reaching January's peak, months like October and December 2023 showed robust sales, contributing 846 million and 832 million dollars respectively, which is positive for the holiday season.
# *   **February 2023:** Revenue dipped significantly to 650 million after the January rush, which is a common pattern post-holiday season, but it's important to monitor this transition.
# *   **Mid-Year Resilience:** Despite some fluctuations, months like June 2023 (878 million) show we can maintain strong revenue even outside traditional peak seasons.
# *   **January 2024 Anomaly:** We see a very low revenue figure for January 2024 (just over 3 million dollars). This is an extremely sharp drop compared to last year's performance and likely indicates incomplete data for the month, or a significant issue that needs immediate investigation. We should confirm the data completeness.
#
# **Insights and Marketing Strategies for Underperforming Areas:**
#
# *   **Identify Root Causes for Dips:** For months like September 2023, or if the January 2024 figure is indeed accurate, we need to dig deeper. What specific products or categories contributed to these lower numbers? Was there a lack of promotions, increased competition, or external factors?
# *   **Targeted Promotions:** For products or categories that aren't selling well, consider targeted discounts, "buy one get one" offers, or bundle deals to increase their appeal and clear inventory.
# *   **Highlight Unique Value:** Revisit the marketing messages for less sold products. Are we effectively communicating their unique benefits and how they solve customer problems?
# *   **Seasonal Campaigns:** Leverage seasonal trends. For instance, if certain products historically dip in specific months (like September), preemptively launch compelling campaigns tied to back-to-school, fall activities, or early holiday shopping.
# *   **Improve Visibility:** Ensure less sold products are prominently featured on our website, in marketing emails, and in-store displays. Sometimes, just increasing exposure can make a difference.
# *   **Customer Feedback Loop:** Gather feedback on underperforming products. Are customers finding them too expensive, difficult to use, or do they lack desired features? This can inform product improvements or re-positioning.
# *   **Cross-Promotion and Bundling:** Pair less popular items with top-selling products. For example, "Customers who bought [popular item] also loved [less popular item]."
# *   **Limited-Time Offers:** Create urgency around specific products with limited-time sales events or exclusive offers to encourage immediate purchases.
# *   **Content Marketing:** Develop engaging content (blog posts, videos, social media) that showcases the benefits and use cases of less popular products, driving interest and demand.
# *   **Influencer Partnerships:** Collaborate with relevant influencers who can authentically promote products that are struggling to gain traction, reaching a new and engaged audience.
# *   **Re-evaluate Pricing Strategy:** For products consistently underperforming, review the pricing strategy. Is it competitive? Could a slight adjustment stimulate sales without significantly impacting margins?
# *   **Expand Distribution Channels:** If possible, explore new sales channels or marketplaces for products that aren't performing well in existing channels.
# *   **Employee Training:** Ensure our sales teams are well-versed in the features and benefits of all products, especially those that might need an extra push, so they can effectively recommend them to customers.

# %%
os.makedirs("reports", exist_ok=True)
with open("reports/insight_report.txt", "w") as f:
    f.write(explanation)

# %%
with open("reports/insight_report.txt", "w") as f:
    f.write(explanation)

plt.savefig('output_plot.png')
print("Report saved!")
# Out:
# Report saved!

# %%
summary_text = "This is an automatically generated insight report."

images = ["output_plot.png"]

pdf_path = report_gen.generate_report(
    title="AI Generated Data Analysis Report",
    summary=summary_text,
    images=images
)

pdf_path
# Out:
# 'report_20251203_173925.pdf'

# %%
summary_text = explanation  # from explanation_agent

# %%
def generate_full_report(user_query):
    # 1. Generate code
    raw = code_gen.generate(user_query, df)
    cleaned = clean_code(raw)
    code = fix_seaborn_palette(cleaned)

    # 2. Execute code
    local_env = {"df": df, "plt": plt, "sns": sns, "pd": pd, "np": np}
    
    # remove old image
    if os.path.exists("output_plot.png"):
        os.remove("output_plot.png")

    exec_output = capture_output(code, local_env)

    # Auto debug
    if "ERROR" in exec_output:
        repaired = auto_debug_code(code, exec_output)
        repaired = clean_code(repaired)
        code = repaired
        exec_output = capture_output(code, local_env)

    # 3. Verify the plot
    print("Plot Exists:", os.path.exists("output_plot.png"))
    
    if not os.path.exists("output_plot.png"):
        raise Exception("The plot was not created, so report cannot be generated.")
    
    print("Plot file size:", os.path.getsize("output_plot.png"))

    # 4. Explanation
    python_summary = exec_output[:500]
    explanation = exp_agent.explain(user_query, python_summary)

    # 5. Generate report
    report_path = report_gen.generate_report(
        title=f"Report: {user_query}",
        summary=explanation,
        images=["output_plot.png"]
    )

    return explanation, report_path

# %%
summary, report_file = generate_full_report("Show total revenue per month")
summary, report_file
# Out:
# Plot Exists: True
# Plot file size: 132941
# ('Here\'s a breakdown of our monthly revenue findings, presented in clear, human language, along with some strategic recommendations:\n\n*   We\'ve analyzed our total revenue for each month, covering all of 2023 and the beginning of 2024.\n*   Overall, 2023 was a strong year, with revenue consistently in the hundreds of millions each month.\n*   Our best-performing month by far was **January 2023**, where we generated an impressive **over $1 billion** in sales. This provided an exceptionally strong start to the year.\n*   Other robust months included **August**, bringing in over **$911 million**, and **June**, with nearly **$879 million**.\n*   **October** also showed solid performance, achieving over **$846 million** in revenue.\n*   The lowest sales month within 2023 was **September**, which saw revenue drop to approximately **$582 million**. This was the only month below the $600 million mark.\n*   Other relatively quieter months in 2023 included **February** (around $650 million), **July** (approximately $687 million), and **November** (about $689 million).\n*   While there are fluctuations, there isn\'t a single, strong, predictable seasonal pattern evident across all months in 2023. Revenue had its ups and downs throughout the year.\n*   The first half of 2023 generally maintained strong revenue, with January being a standout.\n*   The latter half of 2023 saw revenue generally stay healthy, though with a noticeable dip in September.\n*   **January 2024** shows a drastically different picture, with only just over **$3.3 million** in sales. This is an extremely low figure compared to any month in 2023, especially when compared to January 2023\'s billion-dollar performance. This significant drop warrants immediate investigation to understand if it\'s incomplete data, a reporting anomaly, or a genuine and concerning decline.\n\n**Marketing Strategies for Lower Sales Periods or Less Sold Products/Categories:**\n\n*   **Targeted Promotions:** During months that historically show lower sales (like September, February, July, or November), consider running special discounts, "buy-one-get-one" offers, or bundled packages to stimulate demand.\n*   **Highlight Unique Value:** For products or categories that aren\'t selling as well, create marketing campaigns that clearly articulate their specific benefits, features, or how they solve a customer problem.\n*   **Increase Visibility:** Ensure these less popular items are prominently featured on your website, in physical stores, or in your email newsletters. Don\'t let them get lost.\n*   **Customer Education:** Develop content (blog posts, videos, infographics) that educates customers about the uses, quality, or story behind less sold products, helping them understand the value.\n*   **Gather Feedback:** Actively solicit customer feedback on these products. Understanding why they\'re not selling well can help you improve the product itself or adjust your marketing message.\n*   **Launch New Bundles/Kits:** Combine a less popular product with a popular one in an attractive bundle to encourage trial and increase overall sales.\n*   **Loyalty Program Incentives:** Offer extra loyalty points or exclusive early access to sales on specific products to members of your loyalty program.\n*   **Social Media Campaigns:** Run targeted campaigns on social media platforms showcasing these products, perhaps with user-generated content or influencer collaborations.\n*   **Seasonal Tie-ins:** If appropriate, try to tie less popular products into relevant seasonal events or holidays with specific themed promotions.\n*   **Re-evaluate Pricing:** Consider if the pricing of these items is aligned with customer expectations and market value. A slight adjustment might make a big difference.',
#  'report_20251203_174028.pdf')
