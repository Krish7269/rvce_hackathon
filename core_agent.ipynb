# %%
# === Load environment variables ===
from dotenv import load_dotenv
import os

# Load .env file from project root
load_dotenv()

# Fetch the API key from .env
my_api_key = os.getenv("GOOGLE_API_KEY")

# Quick check (optional – remove later)
if my_api_key:
    print("API key loaded successfully.")
else:
    print("API key NOT found. Check your .env file.")

# === Configure Gemini API ===
import google.generativeai as genai
genai.configure(api_key=my_api_key)

print("Gemini configured and ready.")
# Out:
# API key loaded successfully.
# Gemini configured and ready.

# %%
model = genai.GenerativeModel("models/gemini-2.5-flash")

# %%
from agents.report_generator import ReportGenerator
report_gen = ReportGenerator()
import os

# %%
import pandas as pd
from agents.data_cleaner import DataCleaner
from agents.visualizer import Visualizer
from agents.forecaster import Forecaster

cleaner = DataCleaner()
viz = Visualizer()
forecaster = Forecaster()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from agent.code_generator import CodeGenerator
from agent.explanation_agent import ExplanationAgent
from agent.utils import capture_output

# Dummy LLM function (replace with ADK later)
def llm(prompt):
    response = model.generate_content(prompt)
    return response.text

code_gen = CodeGenerator(llm)
exp_agent = ExplanationAgent(llm)

# %%
df = pd.read_csv("sample_data/sales.csv")
df.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  03-02-2023       Bob  North       5053.97             18
# 1        1093  21-04-2023       Bob   West       4384.02             17
# 2        1015  21-09-2023     David  South       4631.23             30
# 3        1072  24-08-2023       Bob  South       2167.94             39
# 4        1061  24-03-2023   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# 1           Cash        Retail             West-Bob
# 2  Bank Transfer        Retail          South-David
# 3    Credit Card        Retail            South-Bob
# 4    Credit Card        Online         East-Charlie

# %%
def route_task(task, df):
    task = task.lower()

    if "clean" in task:
        return cleaner.clean(df)

    if "plot" in task or "visualize" in task:
        column = df.columns[1]
        path = viz.generate_plot(df, column)
        return {"plot_path": path}

    if "forecast" in task:
        column = df.columns[1]
        return forecaster.forecast_next(df, column)

    return "Task not understood."

# %%
def ensure_revenue_column(df):
    cols = df.columns.str.lower()

    # CASE 1: Already contains a revenue-like column
    for c in df.columns:
        if "revenue" in c.lower():
            df.rename(columns={c: "revenue"}, inplace=True)
            return df

    # CASE 2: Contains price & units_sold
    price_col = None
    units_col = None

    for c in df.columns:
        if "price" in c.lower():
            price_col = c
        if "unit" in c.lower() or "quantity" in c.lower():
            units_col = c

    if price_col and units_col:
        df["revenue"] = df[price_col] * df[units_col]
        return df

    # CASE 3: No revenue possible
    df["revenue"] = 0
    return df

# %%
df = ensure_revenue_column(df)

# %%
def ask_ai(task):
    df = pd.read_csv("sample_data/sales.csv")
    result = route_task(task, df)
    return result

ask_ai("clean the data")
# Out:
# {'missing_values': {'Product_ID': 0,
#   'Sale_Date': 0,
#   'Sales_Rep': 0,
#   'Region': 0,
#   'Sales_Amount': 0,
#   'Quantity_Sold': 0,
#   'Product_Category': 0,
#   'Unit_Cost': 0,
#   'Unit_Price': 0,
#   'Customer_Type': 0,
#   'Discount': 0,
#   'Payment_Method': 0,
#   'Sales_Channel': 0,
#   'Region_and_Sales_Rep': 0},
#  'duplicates_removed': 0,
#  'cleaned_df':      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
#  0          1052  03-02-2023       Bob  North       5053.97             18
#  1          1093  21-04-2023       Bob   West       4384.02             17
#  2          1015  21-09-2023     David  South       4631.23             30
#  3          1072  24-08-2023       Bob  South       2167.94             39
#  4          1061  24-03-2023   Charlie   East       3750.20             13
#  ..          ...         ...       ...    ...           ...            ...
#  995        1010  15-04-2023   Charlie  North       4733.88              4
#  996        1067  07-09-2023       Bob  North       4716.36             37
#  997        1018  27-04-2023     David  South       7629.70             17
#  998        1100  20-12-2023     David   West       1629.47             39
#  999        1086  16-08-2023     Alice   East       4923.93             48
#
#      Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
#  0          Furniture     152.75      267.22     Returning      0.09
#  1          Furniture    3816.39     4209.44     Returning      0.11
#  2               Food     261.56      371.40     Returning      0.20
#  3           Clothing    4330.03     4467.75           New      0.02
#  4        Electronics     637.37      692.71           New      0.08
#  ..               ...        ...         ...           ...       ...
#  995             Food    4943.03     5442.15     Returning      0.29
#  996         Clothing    1754.32     1856.40           New      0.21
#  997         Clothing     355.72      438.27     Returning      0.06
#  998      Electronics    3685.03     3743.39           New      0.01
#  999             Food    2632.58     2926.68     Returning      0.14
#
#      Payment_Method Sales_Channel Region_and_Sales_Rep
#  0             Cash        Online            North-Bob
#  1             Cash        Retail             West-Bob
#  2    Bank Transfer        Retail          South-David
#  3      Credit Card        Retail            South-Bob
#  4      Credit Card        Online         East-Charlie
#  ..             ...           ...                  ...
#  995           Cash        Online        North-Charlie
#  996  Bank Transfer        Retail            North-Bob
#  997  Bank Transfer        Online          South-David
#  998  Bank Transfer        Online           West-David
#  999           Cash        Online           East-Alice
#
#  [1000 rows x 14 columns]}

# %%
user_query = "Show me the total revenue per month with a bar chart."

# %%
def clean_code(llm_output):
    # remove markdown fences
    code = llm_output.replace("```python", "").replace("```", "")
    
    # keep ALL lines except pure text lines
    cleaned = []
    for line in code.split("\n"):
        if line.strip() == "":
            continue
        
        # remove conversational garbage
        if any(x in line.lower() for x in [
            "here is the code",
            "sure",
            "below is",
            "the following",
            "as requested"
        ]):
            continue
        
        cleaned.append(line)
    
    return "\n".join(cleaned)

def fix_seaborn_palette(code):
    # If LLM adds deprecated seaborn palette usage, remove palette or add legend=False
    if "sns." in code and "palette=" in code and "hue=" not in code:
        code = code.replace("palette=", "legend=False, palette_removed=")
    return code

# %%
import matplotlib.pyplot as plt

def force_png_no_alpha():
    fig = plt.gcf()
    fig.patch.set_facecolor("white")

# %%
def patch_savefig_alpha(code):
    # force PNGs to be saved in RGB mode
    if "plt.savefig" in code:
        code = code.replace(
            "plt.savefig(",
            "plt.gcf().patch.set_facecolor('white'); plt.savefig("
        )
    return code

# %%
import re

def auto_print_last_var(code):
    lines = code.strip().split("\n")
    last_var = None

    for line in reversed(lines):
        if "=" in line and not line.strip().startswith("#"):
            last_var = line.split("=")[0].strip()
            break

    if last_var and f"print({last_var})" not in code:
        code += f"\nprint({last_var})\n"

    return code

# %%
def fix_unclosed_braces(code):
    open_count = code.count("{")
    close_count = code.count("}")

    if open_count > close_count:
        code += "}" * (open_count - close_count)

    return code

# %%
# 1. Generate raw LLM output
raw_code = code_gen.generate(user_query, df)

# 2. Clean the LLM code (remove ```python, etc.)
cleaned_code = clean_code(raw_code)

# 3. Fix seaborn palette usage if necessary
generated_code = fix_seaborn_palette(cleaned_code)
# Inject forced patch before savefig
if "plt.savefig" in generated_code:
    generated_code = generated_code.replace(
        "plt.savefig(",
        "force_png_no_alpha(); plt.savefig("
    )

print("===== RAW CODE =====")
print(raw_code)
print("====================")

print("\n===== CLEANED CODE =====")
print(generated_code)
print("====================")
# Out:
# ===== RAW CODE =====
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Ensure 'Sale_Date' is in datetime format
# df['Sale_Date'] = pd.to_datetime(df['Sale_Date'])
#
# # Extract month and year for grouping
# df['Sale_Month'] = df['Sale_Date'].dt.to_period('M')
#
# # Calculate total revenue per month
# monthly_revenue = df.groupby('Sale_Month')['revenue'].sum().reset_index()
#
# # Sort by month if not already sorted
# monthly_revenue = monthly_revenue.sort_values(by='Sale_Month')
#
# # Convert 'Sale_Month' to string for plotting labels
# monthly_revenue['Sale_Month_Str'] = monthly_revenue['Sale_Month'].dt.strftime('%Y-%m')
#
# # Print the computed monthly revenue
# print(monthly_revenue[['Sale_Month_Str', 'revenue']])
#
# # Create the bar chart
# plt.figure(figsize=(12, 6))
# plt.bar(monthly_revenue['Sale_Month_Str'], monthly_revenue['revenue'], color='skyblue')
#
# plt.xlabel('Month', fontsize=12)
# plt.ylabel('Total Revenue', fontsize=12)
# plt.title('Total Revenue per Month', fontsize=14)
# plt.xticks(rotation=45, ha='right')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()
#
# # Save the plot
# plt.savefig("output_plot.png", format="png", dpi=200, bbox_inches="tight", facecolor="white")
# plt.close()
# ====================
#
# ===== CLEANED CODE =====
# import pandas as pd
# import matplotlib.pyplot as plt
# df['Sale_Date'] = pd.to_datetime(df['Sale_Date'])
# # Extract month and year for grouping
# df['Sale_Month'] = df['Sale_Date'].dt.to_period('M')
# # Calculate total revenue per month
# monthly_revenue = df.groupby('Sale_Month')['revenue'].sum().reset_index()
# # Sort by month if not already sorted
# monthly_revenue = monthly_revenue.sort_values(by='Sale_Month')
# # Convert 'Sale_Month' to string for plotting labels
# monthly_revenue['Sale_Month_Str'] = monthly_revenue['Sale_Month'].dt.strftime('%Y-%m')
# # Print the computed monthly revenue
# print(monthly_revenue[['Sale_Month_Str', 'revenue']])
# # Create the bar chart
# plt.figure(figsize=(12, 6))
# plt.bar(monthly_revenue['Sale_Month_Str'], monthly_revenue['revenue'], color='skyblue')
# plt.xlabel('Month', fontsize=12)
# plt.ylabel('Total Revenue', fontsize=12)
# plt.title('Total Revenue per Month', fontsize=14)
# plt.xticks(rotation=45, ha='right')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()
# # Save the plot
# force_png_no_alpha(); plt.savefig("output_plot.png", format="png", dpi=200, bbox_inches="tight", facecolor="white")
# plt.close()
# ====================

# %%
def auto_debug_code(bad_code, error):
    prompt = f"""
The following Python code produced an error:
{bad_code}

Error:
{error}

Fix the code. Only output corrected Python code.
"""
    return llm(prompt)

# %%
local_env = {"df": df, "plt": plt, "sns": sns, "pd": pd, "np": np, "force_png_no_alpha": force_png_no_alpha}

# Make sure plot file is deleted first
if os.path.exists("output_plot.png"):
    os.remove("output_plot.png")

exec_output = capture_output(generated_code, local_env)
if "ERROR" in exec_output:
    fixed = auto_debug_code(raw_code, exec_output)
    fixed = clean_code(fixed)
    exec_output = capture_output(fixed, local_env)

print(exec_output)

print("Image Exists:", os.path.exists("output_plot.png"))
# Out:
#    Sale_Month_Str       revenue
# 0         2023-01  1.056883e+09
# 1         2023-02  6.507573e+08
# 2         2023-03  7.610588e+08
# 3         2023-04  7.974712e+08
# 4         2023-05  7.596467e+08
# 5         2023-06  8.789984e+08
# 6         2023-07  6.874590e+08
# 7         2023-08  9.110048e+08
# 8         2023-09  5.820823e+08
# 9         2023-10  8.466485e+08
# 10        2023-11  6.896101e+08
# 11        2023-12  8.321018e+08
# 12        2024-01  3.344795e+06
#
# Image Exists: True

# %%
python_summary = exec_output[:500]  # short summary
print(python_summary)
# Out:
#    Sale_Month_Str       revenue
# 0         2023-01  1.056883e+09
# 1         2023-02  6.507573e+08
# 2         2023-03  7.610588e+08
# 3         2023-04  7.974712e+08
# 4         2023-05  7.596467e+08
# 5         2023-06  8.789984e+08
# 6         2023-07  6.874590e+08
# 7         2023-08  9.110048e+08
# 8         2023-09  5.820823e+08
# 9         2023-10  8.466485e+08
# 10        2023-11  6.896101e+08
# 11        2023-12  8.321018e+08
# 12        2024-01  3.344795e+06

# %%
explanation = exp_agent.explain(user_query, python_summary)
print(explanation)
# Out:
# Here's a breakdown of our monthly revenue performance, highlighting key trends and suggesting strategies:
#
# **Overall Revenue Performance Insights:**
#
# *   **Strong Start to 2023:** January 2023 was our highest-performing month, bringing in over 1 billion dollars in revenue. This set a very high benchmark for the year.
# *   **Consistent Performance Through 2023:** Throughout 2023, our monthly revenue generally stayed strong, fluctuating between roughly 580 million and 910 million dollars after the initial January peak.
# *   **Mid-Year Dips and Recoveries:** We observed some revenue dips in months like February (around 650 million) and July (around 687 million), but the business showed good resilience with strong recoveries in subsequent months.
# *   **September was the Lowest in 2023:** September 2023 saw our lowest revenue for the year, at approximately 582 million dollars.
# *   **Strong Finish to 2023:** Revenue picked up significantly towards the end of the year, with October, November, and December showing solid performance, particularly December closing out the year at over 832 million dollars.
# *   **Dramatic Drop in January 2024:** Our revenue for January 2024 stands at a stark contrast, reporting just over 3.3 million dollars. This is an extremely significant decrease compared to January 2023's 1 billion+ and is the lowest figure by a considerable margin. This specific anomaly requires urgent investigation to understand the underlying causes.
#
# **Monthly Highlights (2023):**
#
# *   **January:** Excellent start, exceeding 1 billion dollars.
# *   **February:** Revenue dipped after the January surge, settling at around 650 million dollars.
# *   **March-April-May:** Fairly stable and strong performance, averaging around 770 million dollars each month.
# *   **June:** A noticeable increase, reaching nearly 879 million dollars.
# *   **July:** Saw a dip back down to about 687 million dollars.
# *   **August:** A strong rebound, pushing revenue back up to over 911 million dollars.
# *   **September:** The lowest revenue month of 2023, at approximately 582 million dollars.
# *   **October:** A healthy recovery, bringing in nearly 847 million dollars.
# *   **November:** A slight dip, with revenue around 690 million dollars.
# *   **December:** A strong year-end performance, bringing in over 832 million dollars.
#
# **Marketing Strategies for Lower Revenue Periods (and to boost all sales):**
#
# *   **Target Seasonal Promotions:** For months that consistently show lower revenue (like February, July, and September), plan specific sales events or promotions to drive traffic and purchases.
# *   **Bundle Products:** Offer attractive bundles of products, perhaps pairing popular items with "less sold" categories at a special price to encourage broader purchases.
# *   **Focus on Customer Loyalty:** Implement or enhance loyalty programs that reward repeat purchases, especially during slower months, to ensure continued engagement.
# *   **Data-Driven Campaigns:** Analyze past purchase data to identify what products or categories perform well, even in slower months, and create targeted campaigns around them.
# *   **Content Marketing:** During slower periods, invest in creating engaging content (blogs, social media, videos) that highlights the value and uses of our products, subtly promoting "less sold" items.
# *   **Collaborate and Cross-Promote:** Explore partnerships with complementary businesses or influencers to reach new audiences and drive interest in our offerings.
# *   **Review Pricing & Offers:** Periodically evaluate pricing strategies and consider flash sales or limited-time offers to create urgency and incentivize purchases.
# *   **Gather Customer Feedback:** Use surveys or direct outreach during slower times to understand customer needs and preferences, which can inform product improvements or new offerings.
# *   **Early Bird Promotions for Future Seasons:** For example, in July (a lower month), start promoting early fall collections or back-to-school items to get a head start.
# *   **Address the January 2024 Anomaly:** Given the dramatic drop, we need to immediately investigate potential data errors, significant market changes, operational issues, or unusual events that could explain this sudden decline. This is our top priority.

# %%
os.makedirs("reports", exist_ok=True)
with open("reports/insight_report.txt", "w") as f:
    f.write(explanation)

# %%
with open("reports/insight_report.txt", "w") as f:
    f.write(explanation)

plt.savefig('output_plot.png')
print("Report saved!")
# Out:
# Report saved!

# %%
summary_text = "This is an automatically generated insight report."

images = ["output_plot.png"]

pdf_path = report_gen.generate_report(
    title="AI Generated Data Analysis Report",
    summary=summary_text,
    images=images
)

pdf_path
# Out:
# 'report_20251202_223752.pdf'

# %%
summary_text = explanation  # from explanation_agent

# %%
def generate_full_report(user_query):
    # 1. Generate code
    raw = code_gen.generate(user_query, df)
    cleaned = clean_code(raw)
    code = fix_seaborn_palette(cleaned)

    # 2. Execute code
    local_env = {"df": df, "plt": plt, "sns": sns, "pd": pd, "np": np}
    
    # remove old image
    if os.path.exists("output_plot.png"):
        os.remove("output_plot.png")

    exec_output = capture_output(code, local_env)

    # Auto debug
    if "ERROR" in exec_output:
        repaired = auto_debug_code(code, exec_output)
        repaired = clean_code(repaired)
        code = repaired
        exec_output = capture_output(code, local_env)

    # 3. Verify the plot
    print("Plot Exists:", os.path.exists("output_plot.png"))
    
    if not os.path.exists("output_plot.png"):
        raise Exception("The plot was not created, so report cannot be generated.")
    
    print("Plot file size:", os.path.getsize("output_plot.png"))

    # 4. Explanation
    python_summary = exec_output[:500]
    explanation = exp_agent.explain(user_query, python_summary)

    # 5. Generate report
    report_path = report_gen.generate_report(
        title=f"Report: {user_query}",
        summary=explanation,
        images=["output_plot.png"]
    )

    return explanation, report_path

# %%
summary, report_file = generate_full_report("Show total revenue per month")
summary, report_file
# Out:
# Plot Exists: True
# Plot file size: 61269
# ('Here\'s an explanation of the revenue findings, followed by insights and marketing strategies:\n\n### Revenue Performance Overview\n\nHere\'s what the sales income data tells us about our business:\n\n*   **Overall Performance:** Last year (2023) showed strong total sales, consistently bringing in hundreds of millions of dollars each month, often nearing or exceeding a billion dollars in our best periods.\n*   **Strong Start to 2023:** January 2023 kicked off the year with a remarkable performance, generating over **1 billion dollars** in sales. This was our highest monthly revenue for the entire year.\n*   **February Dip:** Following the January surge, sales in February cooled down significantly to around **651 million dollars**.\n*   **Spring Recovery:** March and April saw sales steadily climb back up, reaching approximately **761 million dollars** in March and nearly **797 million dollars** in April.\n*   **Mid-Year Fluctuation:** May experienced a slight dip to about **760 million dollars**, but June bounced back strong, nearing **879 million dollars** in revenue.\n*   **Summer Slowdown:** July marked a noticeable dip, with sales coming in at about **687 million dollars**, indicating a quieter summer period.\n*   **Late Summer Surge:** August saw a powerful rebound, reaching **911 million dollars** in sales, marking it as our second-best month of the year after January.\n*   **Lowest Point of the Year:** September was our slowest month by a significant margin, bringing in only **582 million dollars**. This is a key area that warrants further investigation.\n*   **Autumn Rebound:** October showed a robust recovery, reaching **847 million dollars** as we headed into the busy holiday shopping season.\n*   **Pre-Holiday Lull:** November experienced a slight dip to around **690 million dollars**, possibly a brief pause before the major year-end rush.\n*   **Strong Year-End:** December concluded the year on a high note with sales of **832 million dollars**, showcasing strong holiday season performance.\n*   **Concerning Start to 2024:** January 2024 currently shows extremely low sales of only **3.3 million dollars**. This is an unusual and very small figure compared to all previous months, strongly suggesting that the data for 2024-01 is incomplete or there\'s a reporting issue that needs immediate checking. It\'s highly unlikely actual sales dropped this dramatically.\n\n### Insights and Marketing Strategies\n\n**Key Insights on Monthly Revenue:**\n\n*   **Peak Months:** January and August were exceptionally strong, hinting at potential seasonal demand or successful campaigns at the start and in late summer.\n*   **Dips to Address:** February, July, and especially September, show significant drops in revenue. These months represent opportunities for improvement.\n*   **Q4 Strength:** The end of the year (October-December) generally saw strong performance, indicating a positive response during the holiday shopping period, although November had a slight dip.\n*   **Data Anomaly in 2024:** The January 2024 figure is a critical outlier and likely an error. It needs immediate verification to understand the true start to the new year.\n\n**Marketing Strategies for Underperforming Periods (e.g., to boost sales in months like September or for categories that might contribute to these dips):**\n\nWhile this data doesn\'t specify product categories, consistent low revenue in certain months often points to underperforming products or categories during those times. Here are some strategies:\n\n1.  **Understand the "Why":** First, deep-dive into the months with lower revenue (e.g., September). What specific products or categories underperformed? Were there any external factors (holidays, competitor promotions, economic news) affecting sales?\n2.  **Targeted Promotions & Bundles:** For products or categories that typically lag, offer special discounts, "buy one get one" deals, or create attractive product bundles to increase their perceiv ...
#  'report_20251202_223816.pdf')
