# %%
# === Load environment variables ===
from dotenv import load_dotenv
import os

# Load .env file from project root
load_dotenv()

# Fetch the API key from .env
my_api_key = os.getenv("GOOGLE_API_KEY")

# Quick check (optional – remove later)
if my_api_key:
    print("API key loaded successfully.")
else:
    print("API key NOT found. Check your .env file.")

# === Configure Gemini API ===
import google.generativeai as genai
genai.configure(api_key=my_api_key)

print("Gemini configured and ready.")
# Out:
# API key loaded successfully.
# Gemini configured and ready.

# %%
model = genai.GenerativeModel("models/gemini-2.5-flash")

# %%
from agents.report_generator import ReportGenerator
report_gen = ReportGenerator()
import os

# %%
import pandas as pd
from agents.data_cleaner import DataCleaner
from agents.visualizer import Visualizer
from agents.forecaster import Forecaster

cleaner = DataCleaner()
viz = Visualizer()
forecaster = Forecaster()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from agent.code_generator import CodeGenerator
from agent.explanation_agent import ExplanationAgent
from agent.utils import capture_output

# Dummy LLM function (replace with ADK later)
def llm(prompt):
    response = model.generate_content(prompt)
    return response.text

code_gen = CodeGenerator(llm)
exp_agent = ExplanationAgent(llm)

# %%
df = pd.read_csv("sample_data/sales.csv")
df.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  03-02-2023       Bob  North       5053.97             18
# 1        1093  21-04-2023       Bob   West       4384.02             17
# 2        1015  21-09-2023     David  South       4631.23             30
# 3        1072  24-08-2023       Bob  South       2167.94             39
# 4        1061  24-03-2023   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# 1           Cash        Retail             West-Bob
# 2  Bank Transfer        Retail          South-David
# 3    Credit Card        Retail            South-Bob
# 4    Credit Card        Online         East-Charlie

# %%
def route_task(task, df):
    task = task.lower()

    if "clean" in task:
        return cleaner.clean(df)

    if "plot" in task or "visualize" in task:
        column = df.columns[1]
        path = viz.generate_plot(df, column)
        return {"plot_path": path}

    if "forecast" in task:
        column = df.columns[1]
        return forecaster.forecast_next(df, column)

    return "Task not understood."

# %%
def ensure_revenue_column(df):
    cols = df.columns.str.lower()

    # CASE 1: Already contains a revenue-like column
    for c in df.columns:
        if "revenue" in c.lower():
            df.rename(columns={c: "revenue"}, inplace=True)
            return df

    # CASE 2: Contains price & units_sold
    price_col = None
    units_col = None

    for c in df.columns:
        if "price" in c.lower():
            price_col = c
        if "unit" in c.lower() or "quantity" in c.lower():
            units_col = c

    if price_col and units_col:
        df["revenue"] = df[price_col] * df[units_col]
        return df

    # CASE 3: No revenue possible
    df["revenue"] = 0
    return df

# %%
df = ensure_revenue_column(df)

# %%
def ask_ai(task):
    df = pd.read_csv("sample_data/sales.csv")
    result = route_task(task, df)
    return result

ask_ai("clean the data")
# Out:
# {'missing_values': {'Product_ID': 0,
#   'Sale_Date': 0,
#   'Sales_Rep': 0,
#   'Region': 0,
#   'Sales_Amount': 0,
#   'Quantity_Sold': 0,
#   'Product_Category': 0,
#   'Unit_Cost': 0,
#   'Unit_Price': 0,
#   'Customer_Type': 0,
#   'Discount': 0,
#   'Payment_Method': 0,
#   'Sales_Channel': 0,
#   'Region_and_Sales_Rep': 0},
#  'duplicates_removed': 0,
#  'cleaned_df':      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
#  0          1052  03-02-2023       Bob  North       5053.97             18
#  1          1093  21-04-2023       Bob   West       4384.02             17
#  2          1015  21-09-2023     David  South       4631.23             30
#  3          1072  24-08-2023       Bob  South       2167.94             39
#  4          1061  24-03-2023   Charlie   East       3750.20             13
#  ..          ...         ...       ...    ...           ...            ...
#  995        1010  15-04-2023   Charlie  North       4733.88              4
#  996        1067  07-09-2023       Bob  North       4716.36             37
#  997        1018  27-04-2023     David  South       7629.70             17
#  998        1100  20-12-2023     David   West       1629.47             39
#  999        1086  16-08-2023     Alice   East       4923.93             48
#
#      Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
#  0          Furniture     152.75      267.22     Returning      0.09
#  1          Furniture    3816.39     4209.44     Returning      0.11
#  2               Food     261.56      371.40     Returning      0.20
#  3           Clothing    4330.03     4467.75           New      0.02
#  4        Electronics     637.37      692.71           New      0.08
#  ..               ...        ...         ...           ...       ...
#  995             Food    4943.03     5442.15     Returning      0.29
#  996         Clothing    1754.32     1856.40           New      0.21
#  997         Clothing     355.72      438.27     Returning      0.06
#  998      Electronics    3685.03     3743.39           New      0.01
#  999             Food    2632.58     2926.68     Returning      0.14
#
#      Payment_Method Sales_Channel Region_and_Sales_Rep
#  0             Cash        Online            North-Bob
#  1             Cash        Retail             West-Bob
#  2    Bank Transfer        Retail          South-David
#  3      Credit Card        Retail            South-Bob
#  4      Credit Card        Online         East-Charlie
#  ..             ...           ...                  ...
#  995           Cash        Online        North-Charlie
#  996  Bank Transfer        Retail            North-Bob
#  997  Bank Transfer        Online          South-David
#  998  Bank Transfer        Online           West-David
#  999           Cash        Online           East-Alice
#
#  [1000 rows x 14 columns]}

# %%
user_query = "Show me the total revenue per month with a bar chart."

# %%
def clean_code(llm_output):
    # remove markdown fences
    code = llm_output.replace("```python", "").replace("```", "")
    
    # keep ALL lines except pure text lines
    cleaned = []
    for line in code.split("\n"):
        if line.strip() == "":
            continue
        
        # remove conversational garbage
        if any(x in line.lower() for x in [
            "here is the code",
            "sure",
            "below is",
            "the following",
            "as requested"
        ]):
            continue
        
        cleaned.append(line)
    
    return "\n".join(cleaned)

def fix_seaborn_palette(code):
    # If LLM adds deprecated seaborn palette usage, remove palette or add legend=False
    if "sns." in code and "palette=" in code and "hue=" not in code:
        code = code.replace("palette=", "legend=False, palette_removed=")
    return code

# %%
import matplotlib.pyplot as plt

def force_png_no_alpha():
    fig = plt.gcf()
    fig.patch.set_facecolor("white")

# %%
def patch_savefig_alpha(code):
    # force PNGs to be saved in RGB mode
    if "plt.savefig" in code:
        code = code.replace(
            "plt.savefig(",
            "plt.gcf().patch.set_facecolor('white'); plt.savefig("
        )
    return code

# %%
import re

def auto_print_last_var(code):
    lines = code.strip().split("\n")
    last_var = None

    for line in reversed(lines):
        if "=" in line and not line.strip().startswith("#"):
            last_var = line.split("=")[0].strip()
            break

    if last_var and f"print({last_var})" not in code:
        code += f"\nprint({last_var})\n"

    return code

# %%
def fix_unclosed_braces(code):
    open_count = code.count("{")
    close_count = code.count("}")

    if open_count > close_count:
        code += "}" * (open_count - close_count)

    return code

# %%
# 1. Generate raw LLM output
raw_code = code_gen.generate(user_query, df)

# 2. Clean the LLM code (remove ```python, etc.)
cleaned_code = clean_code(raw_code)

# 3. Fix seaborn palette usage if necessary
generated_code = fix_seaborn_palette(cleaned_code)
# Inject forced patch before savefig
if "plt.savefig" in generated_code:
    generated_code = generated_code.replace(
        "plt.savefig(",
        "force_png_no_alpha(); plt.savefig("
    )

print("===== RAW CODE =====")
print(raw_code)
print("====================")

print("\n===== CLEANED CODE =====")
print(generated_code)
print("====================")
# Out:
# ===== RAW CODE =====
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Ensure 'Sale_Date' is in datetime format
# df['Sale_Date'] = pd.to_datetime(df['Sale_Date'])
#
# # Extract the month from the 'Sale_Date'
# df['Sale_Month'] = df['Sale_Date'].dt.to_period('M')
#
# # Calculate total revenue per month
# monthly_revenue = df.groupby('Sale_Month')['revenue'].sum().reset_index()
#
# # Sort by month for correct plotting order
# monthly_revenue = monthly_revenue.sort_values(by='Sale_Month')
#
# # Convert 'Sale_Month' back to string for better x-axis labels if needed, or keep as Period for plotting
# monthly_revenue['Sale_Month_Str'] = monthly_revenue['Sale_Month'].astype(str)
#
# # Print the computed values
# print("Total Revenue Per Month:")
# print(monthly_revenue[['Sale_Month_Str', 'revenue']])
#
# # Create the bar chart
# plt.figure(figsize=(12, 7))
# plt.bar(monthly_revenue['Sale_Month_Str'], monthly_revenue['revenue'], color='skyblue')
#
# plt.xlabel('Month')
# plt.ylabel('Total Revenue')
# plt.title('Total Revenue Per Month')
# plt.xticks(rotation=45, ha='right')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()
#
# # Save the plot
# plt.savefig("output_plot.png", format="png", dpi=200, bbox_inches="tight", facecolor="white")
# plt.close()
# ====================
#
# ===== CLEANED CODE =====
# import pandas as pd
# import matplotlib.pyplot as plt
# df['Sale_Date'] = pd.to_datetime(df['Sale_Date'])
# # Extract the month from the 'Sale_Date'
# df['Sale_Month'] = df['Sale_Date'].dt.to_period('M')
# # Calculate total revenue per month
# monthly_revenue = df.groupby('Sale_Month')['revenue'].sum().reset_index()
# # Sort by month for correct plotting order
# monthly_revenue = monthly_revenue.sort_values(by='Sale_Month')
# # Convert 'Sale_Month' back to string for better x-axis labels if needed, or keep as Period for plotting
# monthly_revenue['Sale_Month_Str'] = monthly_revenue['Sale_Month'].astype(str)
# # Print the computed values
# print("Total Revenue Per Month:")
# print(monthly_revenue[['Sale_Month_Str', 'revenue']])
# # Create the bar chart
# plt.figure(figsize=(12, 7))
# plt.bar(monthly_revenue['Sale_Month_Str'], monthly_revenue['revenue'], color='skyblue')
# plt.xlabel('Month')
# plt.ylabel('Total Revenue')
# plt.title('Total Revenue Per Month')
# plt.xticks(rotation=45, ha='right')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()
# # Save the plot
# force_png_no_alpha(); plt.savefig("output_plot.png", format="png", dpi=200, bbox_inches="tight", facecolor="white")
# plt.close()
# ====================

# %%
def auto_debug_code(bad_code, error):
    prompt = f"""
The following Python code produced an error:
{bad_code}

Error:
{error}

Fix the code. Only output corrected Python code.
"""
    return llm(prompt)

# %%
local_env = {"df": df, "plt": plt, "sns": sns, "pd": pd, "np": np, "force_png_no_alpha": force_png_no_alpha}

# Make sure plot file is deleted first
if os.path.exists("output_plot.png"):
    os.remove("output_plot.png")

exec_output = capture_output(generated_code, local_env)
if "ERROR" in exec_output:
    fixed = auto_debug_code(raw_code, exec_output)
    fixed = clean_code(fixed)
    exec_output = capture_output(fixed, local_env)

print(exec_output)

print("Image Exists:", os.path.exists("output_plot.png"))
# Out:
# Total Revenue Per Month:
#    Sale_Month_Str       revenue
# 0         2023-01  1.056883e+09
# 1         2023-02  6.507573e+08
# 2         2023-03  7.610588e+08
# 3         2023-04  7.974712e+08
# 4         2023-05  7.596467e+08
# 5         2023-06  8.789984e+08
# 6         2023-07  6.874590e+08
# 7         2023-08  9.110048e+08
# 8         2023-09  5.820823e+08
# 9         2023-10  8.466485e+08
# 10        2023-11  6.896101e+08
# 11        2023-12  8.321018e+08
# 12        2024-01  3.344795e+06
#
# Image Exists: True

# %%
python_summary = exec_output[:500]  # short summary
print(python_summary)
# Out:
# Total Revenue Per Month:
#    Sale_Month_Str       revenue
# 0         2023-01  1.056883e+09
# 1         2023-02  6.507573e+08
# 2         2023-03  7.610588e+08
# 3         2023-04  7.974712e+08
# 4         2023-05  7.596467e+08
# 5         2023-06  8.789984e+08
# 6         2023-07  6.874590e+08
# 7         2023-08  9.110048e+08
# 8         2023-09  5.820823e+08
# 9         2023-10  8.466485e+08
# 10        2023-11  6.896101e+08
# 11        2023-12  8.321018e+08
# 12        2024-01  3.344795e+06

# %%
explanation = exp_agent.explain(user_query, python_summary)
print(explanation)
# Out:
# Here's an explanation of your monthly revenue findings, presented in clear language, along with insights and general marketing strategies.
#
# ### Total Revenue Per Month: Key Findings & Insights
#
# 1.  **Overall Strong Performance in 2023:** Across 2023, our business consistently generated substantial revenue, generally ranging from hundreds of millions to over a billion dollars each month.
# 2.  **Exceptional Start to 2023:** January 2023 was an outstanding month, bringing in over 1 billion dollars in revenue. This was the highest point observed in the entire period.
# 3.  **Post-New Year Dip:** Following the January peak, February 2023 saw a significant decrease, with revenue dropping to around 650 million dollars.
# 4.  **Steady Mid-Spring:** Revenue in March and April 2023 showed a modest recovery, settling into the range of 760-790 million dollars.
# 5.  **Summer Rise and Fall:** June 2023 was another strong month, with nearly 880 million dollars in revenue. However, July experienced a dip to about 687 million dollars.
# 6.  **Late Summer Resurgence:** August 2023 saw a healthy rebound, generating over 911 million dollars, making it one of our top-performing months.
# 7.  **Lowest Point of 2023:** September 2023 was the weakest month, with revenue just under 582 million dollars, marking the lowest performance for the year.
# 8.  **Autumn Recovery:** We saw good recovery in October 2023, with sales bouncing back to over 846 million dollars.
# 9.  **Pre-Holiday Lull:** November 2023 experienced another slowdown, bringing in just under 690 million dollars, similar to the levels seen in February and July.
# 10. **Strong Year-End Finish:** December 2023 ended the year on a high note, with revenue exceeding 832 million dollars, indicating strong holiday season sales.
# 11. **Cyclical Pattern in 2023:** Throughout 2023, we observed a pattern of strong revenue months often followed by periods of lower sales, suggesting some seasonality or specific event-driven peaks and troughs.
# 12. **Dramatic Drop in Early 2024:** The most striking observation is for January 2024, where the reported revenue is an extremely low 3.3 million dollars.
# 13. **Significant Discrepancy:** This January 2024 figure is drastically different from any month in 2023, especially when compared to the over 1 billion dollars generated in January 2023.
# 14. **Urgent Investigation Needed for 2024 Data:** This massive drop for January 2024 requires immediate investigation. It could indicate that the data is incomplete (e.g., only partial month's sales), a data error, or a severe and sudden downturn in business. Without clarification, it's a significant red flag.
#
# ---
#
# ### Marketing Strategies for Improving Revenue (Especially in Lower-Performing Months)
#
# Based on the observed dips in months like February, July, September, November, and the concerning figure for January 2024, here are general strategies to boost sales. (Please note: The provided data does not include details on specific products or categories, so these strategies are focused on overall monthly revenue improvement.)
#
# 1.  **Targeted Monthly Promotions:** Launch special campaigns or discounts specifically for traditionally slower months (e.g., a "February Refresh Sale," "Summer Savings in July," or "Autumn Deals in September") to stimulate demand.
# 2.  **Seasonal Marketing Themes:** Align marketing efforts with relevant seasonal events or holidays, even minor ones. For example, back-to-school promotions in August/September, or early-bird holiday shopping incentives in November.
# 3.  **Customer Loyalty Programs:** Encourage repeat purchases during quieter periods by offering exclusive benefits, points, or early access to sales for loyal customers.
# 4.  **Bundle Deals:** Create attractive product bundles or multi-buy offers to increase the average order value during months with lower individual sales.
# 5.  **Content Marketing and Engagement:** Focus on building brand awareness and customer engagement through valuable content (blogs, social media campaigns, how-to guides) that educates or entertains, keeping your audience interested even when they're not actively buying.
# 6.  **Strategic Product Launches:** Consider strategically timing the launch of new products or major updates to existing ones during historically slower months to generate excitement and traffic.
# 7.  **Feedback and Research:** Utilize slower periods to gather customer feedback through surveys or focus groups. Understanding customer needs and preferences can inform future product development and marketing messages, leading to better sales.
# 8.  **Partnerships and Collaborations:** Explore collaborations with complementary businesses or influencers to tap into new audiences and create buzz during off-peak times.
# 9.  **Early Bird Offers for Peaks:** For months that traditionally perform well (like December), consider introducing early bird discounts or pre-orders in the preceding slower months (like November) to pull sales forward.
# 10. **Investigate and Address January 2024:** Immediately investigate the drastically low January 2024 revenue. If it's incomplete data, get the full picture. If it's a real drop, urgent analysis is needed to understand the cause (e.g., changes in market, competition, internal issues) and develop a recovery plan.

# %%
os.makedirs("reports", exist_ok=True)
with open("reports/insight_report.txt", "w") as f:
    f.write(explanation)

# %%
with open("reports/insight_report.txt", "w") as f:
    f.write(explanation)

plt.savefig('output_plot.png')
print("Report saved!")
# Out:
# Report saved!

# %%
summary_text = "This is an automatically generated insight report."

images = ["output_plot.png"]

pdf_path = report_gen.generate_report(
    title="AI Generated Data Analysis Report",
    summary=summary_text,
    images=images
)

pdf_path
# Out:
# 'report_20251203_143614.pdf'

# %%
summary_text = explanation  # from explanation_agent

# %%
def generate_full_report(user_query):
    # 1. Generate code
    raw = code_gen.generate(user_query, df)
    cleaned = clean_code(raw)
    code = fix_seaborn_palette(cleaned)

    # 2. Execute code
    local_env = {"df": df, "plt": plt, "sns": sns, "pd": pd, "np": np}
    
    # remove old image
    if os.path.exists("output_plot.png"):
        os.remove("output_plot.png")

    exec_output = capture_output(code, local_env)

    # Auto debug
    if "ERROR" in exec_output:
        repaired = auto_debug_code(code, exec_output)
        repaired = clean_code(repaired)
        code = repaired
        exec_output = capture_output(code, local_env)

    # 3. Verify the plot
    print("Plot Exists:", os.path.exists("output_plot.png"))
    
    if not os.path.exists("output_plot.png"):
        raise Exception("The plot was not created, so report cannot be generated.")
    
    print("Plot file size:", os.path.getsize("output_plot.png"))

    # 4. Explanation
    python_summary = exec_output[:500]
    explanation = exp_agent.explain(user_query, python_summary)

    # 5. Generate report
    report_path = report_gen.generate_report(
        title=f"Report: {user_query}",
        summary=explanation,
        images=["output_plot.png"]
    )

    return explanation, report_path

# %%
summary, report_file = generate_full_report("Show total revenue per month")
summary, report_file
# Out:
# Plot Exists: True
# Plot file size: 62914
# ("Here's a breakdown of our monthly revenue performance, with insights and strategic recommendations:\n\n**Revenue Performance Insights (2023-2024):**\n\n1.  Our revenue performance showed significant fluctuations throughout 2023, generally maintaining a strong level of several hundred million dollars each month.\n2.  We started **January 2023** with an exceptionally strong performance, bringing in over 1 billion dollars, marking our highest revenue month.\n3.  Following this strong start, **February 2023** saw a noticeable dip to about 650 million dollars, a considerable drop from January's peak.\n4.  Revenue then steadily recovered through **March and April 2023**, reaching close to 800 million dollars in each of these months.\n5.  **May 2023** experienced a slight decrease, with revenue around 760 million dollars, before seeing a good rebound in **June 2023** to nearly 880 million dollars.\n6.  Another significant dip occurred in **July 2023**, with revenue falling back to just under 700 million dollars.\n7.  However, **August 2023** marked a strong recovery, becoming our second-highest revenue month at over 910 million dollars.\n8.  **September 2023** proved to be our weakest month of the entire year, with revenue plummeting significantly to just over 580 million dollars. This sharp decline warrants further investigation.\n9.  We saw a healthy rebound in **October 2023**, achieving over 840 million dollars.\n10. **November 2023** dipped again to approximately 690 million dollars, leading into the end of the year.\n11. **December 2023** closed the year on a strong note, with revenue around 830 million dollars.\n12. The data for **January 2024** currently shows a very low figure of 3.3 million dollars. This strongly suggests the data is incomplete or only represents a very small portion of the month's sales, and needs immediate verification.\n13. Overall, 2023 highlighted peak performance in the early and late summer months (January, August), with a clear low point in September. Understanding the specific factors behind these monthly fluctuations is crucial for future planning.\n\n**Marketing Strategies for Less Sold Products/Categories:**\n\n*(Please note: While this analysis focuses on total monthly revenue, to strategize for specific less-sold products or categories, we would need more detailed sales data. However, here are general marketing strategies that could be employed once such data is available):*\n\n14. **Targeted Promotions:** Launch special offers, discounts, or 'buy-one-get-one' deals specifically for underperforming items to make them more attractive to customers.\n15. **Increase Visibility:** Feature these products more prominently across our sales channels, such as on the homepage of our website, in dedicated email campaigns, or at strategic points within physical stores.\n16. **Re-evaluate Product Messaging:** Refresh how we describe the product, highlighting unique benefits, features, or specific use cases that might not be obvious to customers.\n17. **Bundle with Popular Items:** Pair less popular products with our high-demand items in attractive bundles or special packages to introduce them to a wider audience.\n18. **Gather Customer Feedback:** Actively seek input from customers through surveys, reviews, or direct interactions to understand any perceived shortcomings or barriers to purchase, and then address these.\n19. **Run Social Media Campaigns:** Create engaging content for social media platforms that showcases these products through user-generated content, tutorials, or influencer collaborations.",
#  'report_20251203_143647.pdf')
