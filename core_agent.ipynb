# %%
# === Load environment variables ===
from dotenv import load_dotenv
import os

# Load .env file from project root
load_dotenv()

# Fetch the API key from .env
my_api_key = os.getenv("GOOGLE_API_KEY")

# Quick check (optional – remove later)
if my_api_key:
    print("API key loaded successfully.")
else:
    print("API key NOT found. Check your .env file.")

# === Configure Gemini API ===
import google.generativeai as genai
genai.configure(api_key=my_api_key)

print("Gemini configured and ready.")
# Out:
# API key loaded successfully.
# Gemini configured and ready.

# %%
model = genai.GenerativeModel("models/gemini-2.5-flash")

# %%
from agents.report_generator import ReportGenerator
report_gen = ReportGenerator()
import os

# %%
import pandas as pd
from agents.data_cleaner import DataCleaner
from agents.visualizer import Visualizer
from agents.forecaster import Forecaster

cleaner = DataCleaner()
viz = Visualizer()
forecaster = Forecaster()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from agent.code_generator import CodeGenerator
from agent.explanation_agent import ExplanationAgent
from agent.utils import capture_output

# Dummy LLM function (replace with ADK later)
def llm(prompt):
    response = model.generate_content(prompt)
    return response.text

code_gen = CodeGenerator(llm)
exp_agent = ExplanationAgent(llm)

# %%
df = pd.read_csv("sample_data/sales.csv")
df.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  03-02-2023       Bob  North       5053.97             18
# 1        1093  21-04-2023       Bob   West       4384.02             17
# 2        1015  21-09-2023     David  South       4631.23             30
# 3        1072  24-08-2023       Bob  South       2167.94             39
# 4        1061  24-03-2023   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# 1           Cash        Retail             West-Bob
# 2  Bank Transfer        Retail          South-David
# 3    Credit Card        Retail            South-Bob
# 4    Credit Card        Online         East-Charlie

# %%
def route_task(task, df):
    task = task.lower()

    if "clean" in task:
        return cleaner.clean(df)

    if "plot" in task or "visualize" in task:
        column = df.columns[1]
        path = viz.generate_plot(df, column)
        return {"plot_path": path}

    if "forecast" in task:
        column = df.columns[1]
        return forecaster.forecast_next(df, column)

    return "Task not understood."

# %%
def ensure_revenue_column(df):
    cols = df.columns.str.lower()

    # CASE 1: Already contains a revenue-like column
    for c in df.columns:
        if "revenue" in c.lower():
            df.rename(columns={c: "revenue"}, inplace=True)
            return df

    # CASE 2: Contains price & units_sold
    price_col = None
    units_col = None

    for c in df.columns:
        if "price" in c.lower():
            price_col = c
        if "unit" in c.lower() or "quantity" in c.lower():
            units_col = c

    if price_col and units_col:
        df["revenue"] = df[price_col] * df[units_col]
        return df

    # CASE 3: No revenue possible
    df["revenue"] = 0
    return df

# %%
df = ensure_revenue_column(df)

# %%
def ask_ai(task):
    df = pd.read_csv("sample_data/sales.csv")
    result = route_task(task, df)
    return result

ask_ai("clean the data")
# Out:
# {'missing_values': {'Product_ID': 0,
#   'Sale_Date': 0,
#   'Sales_Rep': 0,
#   'Region': 0,
#   'Sales_Amount': 0,
#   'Quantity_Sold': 0,
#   'Product_Category': 0,
#   'Unit_Cost': 0,
#   'Unit_Price': 0,
#   'Customer_Type': 0,
#   'Discount': 0,
#   'Payment_Method': 0,
#   'Sales_Channel': 0,
#   'Region_and_Sales_Rep': 0},
#  'duplicates_removed': 0,
#  'cleaned_df':      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
#  0          1052  03-02-2023       Bob  North       5053.97             18
#  1          1093  21-04-2023       Bob   West       4384.02             17
#  2          1015  21-09-2023     David  South       4631.23             30
#  3          1072  24-08-2023       Bob  South       2167.94             39
#  4          1061  24-03-2023   Charlie   East       3750.20             13
#  ..          ...         ...       ...    ...           ...            ...
#  995        1010  15-04-2023   Charlie  North       4733.88              4
#  996        1067  07-09-2023       Bob  North       4716.36             37
#  997        1018  27-04-2023     David  South       7629.70             17
#  998        1100  20-12-2023     David   West       1629.47             39
#  999        1086  16-08-2023     Alice   East       4923.93             48
#
#      Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
#  0          Furniture     152.75      267.22     Returning      0.09
#  1          Furniture    3816.39     4209.44     Returning      0.11
#  2               Food     261.56      371.40     Returning      0.20
#  3           Clothing    4330.03     4467.75           New      0.02
#  4        Electronics     637.37      692.71           New      0.08
#  ..               ...        ...         ...           ...       ...
#  995             Food    4943.03     5442.15     Returning      0.29
#  996         Clothing    1754.32     1856.40           New      0.21
#  997         Clothing     355.72      438.27     Returning      0.06
#  998      Electronics    3685.03     3743.39           New      0.01
#  999             Food    2632.58     2926.68     Returning      0.14
#
#      Payment_Method Sales_Channel Region_and_Sales_Rep
#  0             Cash        Online            North-Bob
#  1             Cash        Retail             West-Bob
#  2    Bank Transfer        Retail          South-David
#  3      Credit Card        Retail            South-Bob
#  4      Credit Card        Online         East-Charlie
#  ..             ...           ...                  ...
#  995           Cash        Online        North-Charlie
#  996  Bank Transfer        Retail            North-Bob
#  997  Bank Transfer        Online          South-David
#  998  Bank Transfer        Online           West-David
#  999           Cash        Online           East-Alice
#
#  [1000 rows x 14 columns]}

# %%
user_query = "Show me the total revenue per month with a bar chart."

# %%
def clean_code(llm_output):
    # remove markdown fences
    code = llm_output.replace("```python", "").replace("```", "")
    
    # keep ALL lines except pure text lines
    cleaned = []
    for line in code.split("\n"):
        if line.strip() == "":
            continue
        
        # remove conversational garbage
        if any(x in line.lower() for x in [
            "here is the code",
            "sure",
            "below is",
            "the following",
            "as requested"
        ]):
            continue
        
        cleaned.append(line)
    
    return "\n".join(cleaned)

def fix_seaborn_palette(code):
    # If LLM adds deprecated seaborn palette usage, remove palette or add legend=False
    if "sns." in code and "palette=" in code and "hue=" not in code:
        code = code.replace("palette=", "legend=False, palette_removed=")
    return code

# %%
import matplotlib.pyplot as plt

def force_png_no_alpha():
    fig = plt.gcf()
    fig.patch.set_facecolor("white")

# %%
def patch_savefig_alpha(code):
    # force PNGs to be saved in RGB mode
    if "plt.savefig" in code:
        code = code.replace(
            "plt.savefig(",
            "plt.gcf().patch.set_facecolor('white'); plt.savefig("
        )
    return code

# %%
import re

def auto_print_last_var(code):
    lines = code.strip().split("\n")
    last_var = None

    for line in reversed(lines):
        if "=" in line and not line.strip().startswith("#"):
            last_var = line.split("=")[0].strip()
            break

    if last_var and f"print({last_var})" not in code:
        code += f"\nprint({last_var})\n"

    return code

# %%
def fix_unclosed_braces(code):
    open_count = code.count("{")
    close_count = code.count("}")

    if open_count > close_count:
        code += "}" * (open_count - close_count)

    return code

# %%
# 1. Generate raw LLM output
raw_code = code_gen.generate(user_query, df)

# 2. Clean the LLM code (remove ```python, etc.)
cleaned_code = clean_code(raw_code)

# 3. Fix seaborn palette usage if necessary
generated_code = fix_seaborn_palette(cleaned_code)
# Inject forced patch before savefig
if "plt.savefig" in generated_code:
    generated_code = generated_code.replace(
        "plt.savefig(",
        "force_png_no_alpha(); plt.savefig("
    )

print("===== RAW CODE =====")
print(raw_code)
print("====================")

print("\n===== CLEANED CODE =====")
print(generated_code)
print("====================")
# Out:
# ===== RAW CODE =====
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Ensure 'Sale_Date' is in datetime format
# df['Sale_Date'] = pd.to_datetime(df['Sale_Date'])
#
# # Extract month and year for grouping
# df['Sale_Month'] = df['Sale_Date'].dt.to_period('M')
#
# # Calculate total revenue per month
# monthly_revenue = df.groupby('Sale_Month')['revenue'].sum().reset_index()
#
# # Convert 'Sale_Month' back to string for better plotting labels
# monthly_revenue['Sale_Month'] = monthly_revenue['Sale_Month'].astype(str)
#
# # Print the computed monthly revenue
# print(monthly_revenue)
#
# # Create the bar chart
# plt.figure(figsize=(12, 6))
# plt.bar(monthly_revenue['Sale_Month'], monthly_revenue['revenue'], color='skyblue')
#
# plt.xlabel('Month')
# plt.ylabel('Total Revenue')
# plt.title('Total Revenue per Month')
# plt.xticks(rotation=45, ha='right')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()
#
# # Save the plot
# plt.savefig("output_plot.png", format="png", dpi=200, bbox_inches="tight", facecolor="white")
# plt.close()
# ====================
#
# ===== CLEANED CODE =====
# import pandas as pd
# import matplotlib.pyplot as plt
# df['Sale_Date'] = pd.to_datetime(df['Sale_Date'])
# # Extract month and year for grouping
# df['Sale_Month'] = df['Sale_Date'].dt.to_period('M')
# # Calculate total revenue per month
# monthly_revenue = df.groupby('Sale_Month')['revenue'].sum().reset_index()
# # Convert 'Sale_Month' back to string for better plotting labels
# monthly_revenue['Sale_Month'] = monthly_revenue['Sale_Month'].astype(str)
# # Print the computed monthly revenue
# print(monthly_revenue)
# # Create the bar chart
# plt.figure(figsize=(12, 6))
# plt.bar(monthly_revenue['Sale_Month'], monthly_revenue['revenue'], color='skyblue')
# plt.xlabel('Month')
# plt.ylabel('Total Revenue')
# plt.title('Total Revenue per Month')
# plt.xticks(rotation=45, ha='right')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()
# # Save the plot
# force_png_no_alpha(); plt.savefig("output_plot.png", format="png", dpi=200, bbox_inches="tight", facecolor="white")
# plt.close()
# ====================

# %%
def auto_debug_code(bad_code, error):
    prompt = f"""
The following Python code produced an error:
{bad_code}

Error:
{error}

Fix the code. Only output corrected Python code.
"""
    return llm(prompt)

# %%
local_env = {"df": df, "plt": plt, "sns": sns, "pd": pd, "np": np, "force_png_no_alpha": force_png_no_alpha}

# Make sure plot file is deleted first
if os.path.exists("output_plot.png"):
    os.remove("output_plot.png")

exec_output = capture_output(generated_code, local_env)
if "ERROR" in exec_output:
    fixed = auto_debug_code(raw_code, exec_output)
    fixed = clean_code(fixed)
    exec_output = capture_output(fixed, local_env)

print(exec_output)

print("Image Exists:", os.path.exists("output_plot.png"))
# Out:
#    Sale_Month       revenue
# 0     2023-01  1.056883e+09
# 1     2023-02  6.507573e+08
# 2     2023-03  7.610588e+08
# 3     2023-04  7.974712e+08
# 4     2023-05  7.596467e+08
# 5     2023-06  8.789984e+08
# 6     2023-07  6.874590e+08
# 7     2023-08  9.110048e+08
# 8     2023-09  5.820823e+08
# 9     2023-10  8.466485e+08
# 10    2023-11  6.896101e+08
# 11    2023-12  8.321018e+08
# 12    2024-01  3.344795e+06
#
# Image Exists: True

# %%
python_summary = exec_output[:500]  # short summary
print(python_summary)
# Out:
#    Sale_Month       revenue
# 0     2023-01  1.056883e+09
# 1     2023-02  6.507573e+08
# 2     2023-03  7.610588e+08
# 3     2023-04  7.974712e+08
# 4     2023-05  7.596467e+08
# 5     2023-06  8.789984e+08
# 6     2023-07  6.874590e+08
# 7     2023-08  9.110048e+08
# 8     2023-09  5.820823e+08
# 9     2023-10  8.466485e+08
# 10    2023-11  6.896101e+08
# 11    2023-12  8.321018e+08
# 12    2024-01  3.344795e+06

# %%
explanation = exp_agent.explain(user_query, python_summary)
print(explanation)
# Out:
# Here's an explanation of your monthly revenue findings, presented in clear language, along with some insights and marketing strategies:
#
# ---
#
# **Understanding Our Monthly Sales Performance**
#
# This data shows us how much money we've made in sales each month from January 2023 through the beginning of 2024. Seeing this helps us understand our business's rhythm and identify opportunities.
#
# Here are the key findings and insights:
#
# *   **1. Strong Start to 2023:** We kicked off 2023 with an outstanding performance in **January**, generating over 1 billion dollars in revenue. This was our highest-grossing month of the entire year.
# *   **2. February's Dip:** Following the January peak, **February 2023** saw a significant drop, with sales falling to around 651 million dollars. This is a common pattern after a holiday surge.
# *   **3. Spring Recovery:** Sales started to climb back up through spring, reaching about 761 million dollars in **March** and nearly 797 million dollars in **April**.
# *   **4. May's Stability:** Revenue in **May 2023** remained relatively stable compared to April, staying around 760 million dollars.
# *   **5. Mid-Year Boost:** We saw a healthy increase in **June 2023**, with sales rising to almost 879 million dollars.
# *   **6. Summer Slowdown:** **July 2023** experienced another dip, with revenue falling back to approximately 687 million dollars.
# *   **7. Late Summer Surge:** **August 2023** bounced back strongly, becoming our second-best month of the year with over 911 million dollars in sales.
# *   **8. The Year's Lowest Point:** **September 2023** marked our lowest sales month of the entire year, dropping significantly to just over 582 million dollars. This is a crucial month to investigate further.
# *   **9. Autumn Rebound:** We saw a fantastic recovery in **October 2023**, with sales jumping impressively to 847 million dollars.
# *   **10. Pre-Holiday Dip:** Just before the major holiday season, **November 2023** revenue decreased to about 690 million dollars.
# *   **11. Strong Year-End:** We finished **December 2023** on a positive note, with sales rising to 832 million dollars, showing good activity for the holiday period, though not reaching the very highest points of January or August.
# *   **12. Overall 2023 Pattern:** The year 2023 showed clear peaks in January and August, and notable dips in February, July, September, and November. Understanding these cycles is key for planning.
# *   **13. Incomplete 2024 Data:** The revenue for **January 2024** is extremely low, at only 3.3 million dollars. This figure is highly unusual and suggests the data for this month is either incomplete (e.g., only a few days of sales) or there's an issue with how the data was recorded. This needs immediate investigation to get a true picture.
#
# ---
#
# **Marketing Strategies for Boosting Sales (Especially in Slower Periods or for Less Popular Items):**
#
# Based on the monthly fluctuations and general business needs, here are some strategies to consider:
#
# *   **14. Target Slower Months with Promotions:** During months like February, July, September, and November (when sales naturally dip), plan special promotions, flash sales, or unique bundles to re-engage customers and stimulate demand.
# *   **15. Seasonal Campaigns:** Create specific marketing campaigns tied to seasons or informal holidays (e.g., "Back-to-School" promotions in late summer to potentially offset the September dip, or "Spring Refresh" sales in March).
# *   **16. Feature Less Popular Items:** For products or categories that don't sell as well, consider spotlighting them through dedicated marketing campaigns. Highlight their unique benefits, showcase customer testimonials, or create compelling usage guides.
# *   **17. Bundle and Cross-Sell:** Pair less popular products with best-selling items at a slight discount. This encourages customers to try something new while still getting a deal on what they already want.
# *   **18. Engage with Educational Content:** Sometimes, products don't sell because customers aren't aware of their value or how they fit into their lives. Create blog posts, social media videos, or online workshops that educate customers on the benefits and uses of these specific items.
# *   **19. Loyalty Programs and Exclusive Offers:** Implement or enhance a loyalty program that offers exclusive discounts or early access to new products, especially for items or categories needing a boost.
# *   **20. Gather Direct Feedback:** Actively ask customers why they might not be purchasing certain products or categories. Surveys, social media polls, or direct conversations can reveal insights that guide product improvements or marketing messages.

# %%
os.makedirs("reports", exist_ok=True)
with open("reports/insight_report.txt", "w") as f:
    f.write(explanation)

# %%
with open("reports/insight_report.txt", "w") as f:
    f.write(explanation)

plt.savefig('output_plot.png')
print("Report saved!")
# Out:
# Report saved!

# %%
summary_text = "This is an automatically generated insight report."

images = ["output_plot.png"]

pdf_path = report_gen.generate_report(
    title="AI Generated Data Analysis Report",
    summary=summary_text,
    images=images
)

pdf_path
# Out:
# 'report_20251203_141133.pdf'

# %%
summary_text = explanation  # from explanation_agent

# %%
def generate_full_report(user_query):
    # 1. Generate code
    raw = code_gen.generate(user_query, df)
    cleaned = clean_code(raw)
    code = fix_seaborn_palette(cleaned)

    # 2. Execute code
    local_env = {"df": df, "plt": plt, "sns": sns, "pd": pd, "np": np}
    
    # remove old image
    if os.path.exists("output_plot.png"):
        os.remove("output_plot.png")

    exec_output = capture_output(code, local_env)

    # Auto debug
    if "ERROR" in exec_output:
        repaired = auto_debug_code(code, exec_output)
        repaired = clean_code(repaired)
        code = repaired
        exec_output = capture_output(code, local_env)

    # 3. Verify the plot
    print("Plot Exists:", os.path.exists("output_plot.png"))
    
    if not os.path.exists("output_plot.png"):
        raise Exception("The plot was not created, so report cannot be generated.")
    
    print("Plot file size:", os.path.getsize("output_plot.png"))

    # 4. Explanation
    python_summary = exec_output[:500]
    explanation = exp_agent.explain(user_query, python_summary)

    # 5. Generate report
    report_path = report_gen.generate_report(
        title=f"Report: {user_query}",
        summary=explanation,
        images=["output_plot.png"]
    )

    return explanation, report_path

# %%
summary, report_file = generate_full_report("Show total revenue per month")
summary, report_file
# Out:
# Plot Exists: True
# Plot file size: 64066
# ('Here\'s an explanation of the revenue findings and some strategic recommendations:\n\n**Revenue Performance Overview (January 2023 - January 2024):**\n\n*   We\'ve analyzed our total revenue for each month, starting from January 2023 through January 2024.\n*   Overall, 2023 showed strong sales, but with significant ups and downs throughout the year rather than a consistent upward trend.\n*   Our best-performing month in 2023 was January, kicking off the year with an impressive over $1.05 billion in sales.\n*   Following this strong start, February and March experienced a dip, with sales around $650 million and $760 million, respectively.\n*   Revenue picked up through spring, with April to June generally seeing sales between $750 million and $880 million.\n*   The summer months saw a slight slowdown, with July revenue being around $687 million.\n*   August brought a healthy rebound, nearly reaching $911 million, making it one of the strongest months of the year.\n*   September was our lowest-performing month in 2023, with sales just above $582 million. This represented a notable drop compared to previous months.\n*   The last quarter of 2023 saw sales recover, with October hitting over $846 million.\n*   December closed the year on a strong note, bringing in over $832 million.\n*   A major point of concern is the dramatic drop in January 2024, where recorded revenue was only about $3.3 million. This is an exceptionally low figure and suggests either incomplete data for the month or a severe and sudden issue that requires immediate investigation.\n*   Excluding the anomalous January 2024 data, our monthly revenue in 2023 typically ranged from roughly $580 million to over $1 billion.\n\n**Marketing Strategies for Less Sold Products & Categories:**\n\nTo boost sales for specific products or entire categories that aren\'t performing as well, consider these strategies:\n\n*   **Deep Dive into "Why":** First, we need to understand the underlying reasons. Is it pricing, lack of awareness, competitive pressure, or perceived value?\n*   **Targeted Promotions:** Offer special discounts, "buy one get one" deals, or create attractive product bundles that include these items.\n*   **Increase Visibility:** Feature these products more prominently in stores, on our website\'s homepage, or within email newsletters.\n*   **Educational Content:** Create marketing materials (like blog posts, videos, or social media campaigns) that clearly highlight the benefits, unique features, and different ways to use these products.\n*   **Digital Advertising Campaigns:** Run specific online ad campaigns (e.g., on social media or search engines) targeting customers who might have shown interest in similar products.\n*   **Gather Customer Feedback:** Actively seek reviews and feedback from customers, even those who didn\'t purchase, to identify pain points or areas for improvement.\n*   **Product Repositioning:** Sometimes, changing the way we market a product or identifying a new target audience can significantly boost its appeal.\n*   **Cross-Promotion:** Pair less popular items with our best-selling products as a recommended add-on during the checkout process.\n*   **Influencer Collaborations:** Partner with relevant influencers who can authentically showcase the value of these products to their audience.\n*   **Seasonal Relevance:** Tie promotions for these items to relevant holidays, events, or seasonal needs to create a timely and compelling reason to buy.',
#  'report_20251203_141203.pdf')
