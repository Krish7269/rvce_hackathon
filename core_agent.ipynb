# %%
my_api_key = "AIzaSyAuee6zo8bN0Oh_pMjRjtWS1oVDdoX6ygM"

import google.generativeai as genai
genai.configure(api_key=my_api_key)

# %%
model = genai.GenerativeModel("models/gemini-2.5-flash")

# %%
from agents.report_generator import ReportGenerator
report_gen = ReportGenerator()
import os

# %%
import pandas as pd
from agents.data_cleaner import DataCleaner
from agents.visualizer import Visualizer
from agents.forecaster import Forecaster

cleaner = DataCleaner()
viz = Visualizer()
forecaster = Forecaster()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from agent.code_generator import CodeGenerator
from agent.explanation_agent import ExplanationAgent
from agent.utils import capture_output

# Dummy LLM function (replace with ADK later)
def llm(prompt):
    response = model.generate_content(prompt)
    return response.text

code_gen = CodeGenerator(llm)
exp_agent = ExplanationAgent(llm)

# %%
df = pd.read_csv("sample_data/sales.csv")
df.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  03-02-2023       Bob  North       5053.97             18
# 1        1093  21-04-2023       Bob   West       4384.02             17
# 2        1015  21-09-2023     David  South       4631.23             30
# 3        1072  24-08-2023       Bob  South       2167.94             39
# 4        1061  24-03-2023   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# 1           Cash        Retail             West-Bob
# 2  Bank Transfer        Retail          South-David
# 3    Credit Card        Retail            South-Bob
# 4    Credit Card        Online         East-Charlie

# %%
def route_task(task, df):
    task = task.lower()

    if "clean" in task:
        return cleaner.clean(df)

    if "plot" in task or "visualize" in task:
        column = df.columns[1]
        path = viz.generate_plot(df, column)
        return {"plot_path": path}

    if "forecast" in task:
        column = df.columns[1]
        return forecaster.forecast_next(df, column)

    return "Task not understood."

# %%
def ensure_revenue_column(df):
    cols = df.columns.str.lower()

    # CASE 1: Already contains a revenue-like column
    for c in df.columns:
        if "revenue" in c.lower():
            df.rename(columns={c: "revenue"}, inplace=True)
            return df

    # CASE 2: Contains price & units_sold
    price_col = None
    units_col = None

    for c in df.columns:
        if "price" in c.lower():
            price_col = c
        if "unit" in c.lower() or "quantity" in c.lower():
            units_col = c

    if price_col and units_col:
        df["revenue"] = df[price_col] * df[units_col]
        return df

    # CASE 3: No revenue possible
    df["revenue"] = 0
    return df

# %%
df = ensure_revenue_column(df)

# %%
def ask_ai(task):
    df = pd.read_csv("sample_data/sales.csv")
    result = route_task(task, df)
    return result

ask_ai("clean the data")
# Out:
# {'missing_values': {'Product_ID': 0,
#   'Sale_Date': 0,
#   'Sales_Rep': 0,
#   'Region': 0,
#   'Sales_Amount': 0,
#   'Quantity_Sold': 0,
#   'Product_Category': 0,
#   'Unit_Cost': 0,
#   'Unit_Price': 0,
#   'Customer_Type': 0,
#   'Discount': 0,
#   'Payment_Method': 0,
#   'Sales_Channel': 0,
#   'Region_and_Sales_Rep': 0},
#  'duplicates_removed': 0,
#  'cleaned_df':      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
#  0          1052  03-02-2023       Bob  North       5053.97             18
#  1          1093  21-04-2023       Bob   West       4384.02             17
#  2          1015  21-09-2023     David  South       4631.23             30
#  3          1072  24-08-2023       Bob  South       2167.94             39
#  4          1061  24-03-2023   Charlie   East       3750.20             13
#  ..          ...         ...       ...    ...           ...            ...
#  995        1010  15-04-2023   Charlie  North       4733.88              4
#  996        1067  07-09-2023       Bob  North       4716.36             37
#  997        1018  27-04-2023     David  South       7629.70             17
#  998        1100  20-12-2023     David   West       1629.47             39
#  999        1086  16-08-2023     Alice   East       4923.93             48
#
#      Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
#  0          Furniture     152.75      267.22     Returning      0.09
#  1          Furniture    3816.39     4209.44     Returning      0.11
#  2               Food     261.56      371.40     Returning      0.20
#  3           Clothing    4330.03     4467.75           New      0.02
#  4        Electronics     637.37      692.71           New      0.08
#  ..               ...        ...         ...           ...       ...
#  995             Food    4943.03     5442.15     Returning      0.29
#  996         Clothing    1754.32     1856.40           New      0.21
#  997         Clothing     355.72      438.27     Returning      0.06
#  998      Electronics    3685.03     3743.39           New      0.01
#  999             Food    2632.58     2926.68     Returning      0.14
#
#      Payment_Method Sales_Channel Region_and_Sales_Rep
#  0             Cash        Online            North-Bob
#  1             Cash        Retail             West-Bob
#  2    Bank Transfer        Retail          South-David
#  3      Credit Card        Retail            South-Bob
#  4      Credit Card        Online         East-Charlie
#  ..             ...           ...                  ...
#  995           Cash        Online        North-Charlie
#  996  Bank Transfer        Retail            North-Bob
#  997  Bank Transfer        Online          South-David
#  998  Bank Transfer        Online           West-David
#  999           Cash        Online           East-Alice
#
#  [1000 rows x 14 columns]}

# %%
user_query = "Show me the total revenue per month with a bar chart."

# %%
def clean_code(llm_output):
    # remove markdown fences
    code = llm_output.replace("```python", "").replace("```", "")
    
    # keep ALL lines except pure text lines
    cleaned = []
    for line in code.split("\n"):
        if line.strip() == "":
            continue
        
        # remove conversational garbage
        if any(x in line.lower() for x in [
            "here is the code",
            "sure",
            "below is",
            "the following",
            "as requested"
        ]):
            continue
        
        cleaned.append(line)
    
    return "\n".join(cleaned)

def fix_seaborn_palette(code):
    # If LLM adds deprecated seaborn palette usage, remove palette or add legend=False
    if "sns." in code and "palette=" in code and "hue=" not in code:
        code = code.replace("palette=", "legend=False, palette_removed=")
    return code

# %%
import matplotlib.pyplot as plt

def force_png_no_alpha():
    fig = plt.gcf()
    fig.patch.set_facecolor("white")

# %%
def patch_savefig_alpha(code):
    # force PNGs to be saved in RGB mode
    if "plt.savefig" in code:
        code = code.replace(
            "plt.savefig(",
            "plt.gcf().patch.set_facecolor('white'); plt.savefig("
        )
    return code

# %%
import re

def auto_print_last_var(code):
    lines = code.strip().split("\n")
    last_var = None

    for line in reversed(lines):
        if "=" in line and not line.strip().startswith("#"):
            last_var = line.split("=")[0].strip()
            break

    if last_var and f"print({last_var})" not in code:
        code += f"\nprint({last_var})\n"

    return code

# %%
def fix_unclosed_braces(code):
    open_count = code.count("{")
    close_count = code.count("}")

    if open_count > close_count:
        code += "}" * (open_count - close_count)

    return code

# %%
# 1. Generate raw LLM output
raw_code = code_gen.generate(user_query, df)

# 2. Clean the LLM code (remove ```python, etc.)
cleaned_code = clean_code(raw_code)

# 3. Fix seaborn palette usage if necessary
generated_code = fix_seaborn_palette(cleaned_code)
# Inject forced patch before savefig
if "plt.savefig" in generated_code:
    generated_code = generated_code.replace(
        "plt.savefig(",
        "force_png_no_alpha(); plt.savefig("
    )

print("===== RAW CODE =====")
print(raw_code)
print("====================")

print("\n===== CLEANED CODE =====")
print(generated_code)
print("====================")
# Out:
# ===== RAW CODE =====
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Ensure 'revenue' column exists. If not, calculate it.
# # Based on the dataset columns, 'revenue' already exists.
# if 'revenue' not in df.columns:
#     if 'Unit_Price' in df.columns and 'Quantity_Sold' in df.columns:
#         df['revenue'] = df['Unit_Price'] * df['Quantity_Sold']
#     elif 'Sales_Amount' in df.columns:
#         df['revenue'] = df['Sales_Amount']
#     else:
#         # Fallback to the most relevant numeric column if revenue is still missing
#         # For this dataset, 'Sales_Amount' is a good candidate if 'revenue' was truly absent.
#         # But 'revenue' is explicitly listed, so this path is unlikely.
#         numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
#         if len(numeric_cols) > 0:
#             df['revenue'] = df[numeric_cols[0]]
#         else:
#             raise ValueError("Could not find or compute a 'revenue' column.")
#
# # Convert 'Sale_Date' to datetime
# df['Sale_Date'] = pd.to_datetime(df['Sale_Date'])
#
# # Extract month and year for grouping
# df['Sale_Month'] = df['Sale_Date'].dt.to_period('M')
#
# # Calculate total revenue per month
# monthly_revenue = df.groupby('Sale_Month')['revenue'].sum().reset_index()
#
# # Sort by month
# monthly_revenue['Sale_Month'] = monthly_revenue['Sale_Month'].dt.start_time
# monthly_revenue = monthly_revenue.sort_values(by='Sale_Month')
#
# # Format month for plotting
# monthly_revenue['Month_Label'] = monthly_revenue['Sale_Month'].dt.strftime('%Y-%m')
#
# # Print the computed values
# print(monthly_revenue[['Month_Label', 'revenue']])
#
# # Create the bar chart
# plt.figure(figsize=(12, 6))
# plt.bar(monthly_revenue['Month_Label'], monthly_revenue['revenue'], color='skyblue')
#
# # Add titles and labels
# plt.title('Total Revenue Per Month', fontsize=16)
# plt.xlabel('Month', fontsize=12)
# plt.ylabel('Total Revenue', fontsize=12)
# plt.xticks(rotation=45, ha='right')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()
#
# # Save the plot
# plt.savefig("output_plot.png", format="png", dpi=200, bbox_inches="tight", facecolor="white")
# plt.close()
# ====================
#
# ===== CLEANED CODE =====
# import pandas as pd
# import matplotlib.pyplot as plt
# # Based on the dataset columns, 'revenue' already exists.
# if 'revenue' not in df.columns:
#     if 'Unit_Price' in df.columns and 'Quantity_Sold' in df.columns:
#         df['revenue'] = df['Unit_Price'] * df['Quantity_Sold']
#     elif 'Sales_Amount' in df.columns:
#         df['revenue'] = df['Sales_Amount']
#     else:
#         # Fallback to the most relevant numeric column if revenue is still missing
#         # For this dataset, 'Sales_Amount' is a good candidate if 'revenue' was truly absent.
#         # But 'revenue' is explicitly listed, so this path is unlikely.
#         numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
#         if len(numeric_cols) > 0:
#             df['revenue'] = df[numeric_cols[0]]
#         else:
#             raise ValueError("Could not find or compute a 'revenue' column.")
# # Convert 'Sale_Date' to datetime
# df['Sale_Date'] = pd.to_datetime(df['Sale_Date'])
# # Extract month and year for grouping
# df['Sale_Month'] = df['Sale_Date'].dt.to_period('M')
# # Calculate total revenue per month
# monthly_revenue = df.groupby('Sale_Month')['revenue'].sum().reset_index()
# # Sort by month
# monthly_revenue['Sale_Month'] = monthly_revenue['Sale_Month'].dt.start_time
# monthly_revenue = monthly_revenue.sort_values(by='Sale_Month')
# # Format month for plotting
# monthly_revenue['Month_Label'] = monthly_revenue['Sale_Month'].dt.strftime('%Y-%m')
# # Print the computed values
# print(monthly_revenue[['Month_Label', 'revenue']])
# # Create the bar chart
# plt.figure(figsize=(12, 6))
# plt.bar(monthly_revenue['Month_Label'], monthly_revenue['revenue'], color='skyblue')
# # Add titles and labels
# plt.title('Total Revenue Per Month', fontsize=16)
# plt.xlabel('Month', fontsize=12)
# plt.ylabel('Total Revenue', fontsize=12)
# plt.xticks(rotation=45, ha='right')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()
# # Save the plot
# force_png_no_alpha(); plt.savefig("output_plot.png", format="png", dpi=200, bbox_inches="tight", facecolor="white")
# plt.close()
# ====================

# %%
def auto_debug_code(bad_code, error):
    prompt = f"""
The following Python code produced an error:
{bad_code}

Error:
{error}

Fix the code. Only output corrected Python code.
"""
    return llm(prompt)

# %%
local_env = {"df": df, "plt": plt, "sns": sns, "pd": pd, "np": np, "force_png_no_alpha": force_png_no_alpha}

# Make sure plot file is deleted first
if os.path.exists("output_plot.png"):
    os.remove("output_plot.png")

exec_output = capture_output(generated_code, local_env)
if "ERROR" in exec_output:
    fixed = auto_debug_code(raw_code, exec_output)
    fixed = clean_code(fixed)
    exec_output = capture_output(fixed, local_env)

print(exec_output)

print("Image Exists:", os.path.exists("output_plot.png"))
# Out:
#    Month_Label       revenue
# 0      2023-01  1.056883e+09
# 1      2023-02  6.507573e+08
# 2      2023-03  7.610588e+08
# 3      2023-04  7.974712e+08
# 4      2023-05  7.596467e+08
# 5      2023-06  8.789984e+08
# 6      2023-07  6.874590e+08
# 7      2023-08  9.110048e+08
# 8      2023-09  5.820823e+08
# 9      2023-10  8.466485e+08
# 10     2023-11  6.896101e+08
# 11     2023-12  8.321018e+08
# 12     2024-01  3.344795e+06
#
# Image Exists: True

# %%
python_summary = exec_output[:500]  # short summary
print(python_summary)
# Out:
#    Month_Label       revenue
# 0      2023-01  1.056883e+09
# 1      2023-02  6.507573e+08
# 2      2023-03  7.610588e+08
# 3      2023-04  7.974712e+08
# 4      2023-05  7.596467e+08
# 5      2023-06  8.789984e+08
# 6      2023-07  6.874590e+08
# 7      2023-08  9.110048e+08
# 8      2023-09  5.820823e+08
# 9      2023-10  8.466485e+08
# 10     2023-11  6.896101e+08
# 11     2023-12  8.321018e+08
# 12     2024-01  3.344795e+06

# %%
explanation = exp_agent.explain(user_query, python_summary)
print(explanation)
# Out:
# Here's an analysis of your monthly revenue data, explained in clear, human language, along with some strategic recommendations:
#
# **Revenue Findings and Insights:**
#
# 1.  We've reviewed our total monthly revenue from January 2023 through January 2024, giving us a clear overview of our sales performance.
# 2.  Overall, 2023 was a very strong year, with our company consistently generating hundreds of millions of dollars in revenue each month.
# 3.  The year kicked off exceptionally well: January 2023 recorded our highest revenue by far, surpassing **1 billion dollars**. This set a remarkable benchmark for the year.
# 4.  Following this initial boom, February 2023 saw a significant decrease, with revenue settling at approximately **651 million dollars**.
# 5.  Throughout the spring and early summer, monthly revenue fluctuated but generally remained robust, mostly staying between 650 million and 880 million dollars.
# 6.  August 2023 was another standout month, achieving our second-highest revenue figure at over **911 million dollars**.
# 7.  However, September 2023 marked the lowest full month of revenue for the period, bringing in approximately **582 million dollars**.
# 8.  Other months with comparatively lower revenues included July (around 687 million dollars) and November (around 690 million dollars).
# 9.  We observed a positive rebound towards the end of 2023, with strong performances in October (847 million dollars) and December (832 million dollars).
# 10. The revenue figure for January 2024 currently stands at a very low **3.3 million dollars**. This is highly likely to be incomplete data, possibly representing only the first few days of the month, and shouldn't be compared directly with full previous months.
# 11. The stark difference between the 1-billion-dollar revenue in January 2023 and the current partial data for January 2024 highlights the importance of confirming the completeness of our new year's data.
# 12. The data suggests potential seasonal trends, with strong performances often seen at the beginning of the year and in late summer, followed by dips in other specific months.
#
# **Marketing Strategies for Revenue Growth (especially during historically lower periods):**
#
# 13. To address the dips observed in months like February, July, and September, we should implement focused marketing strategies during these periods.
# 14. **Strategic Promotions:** Introduce special discounts, limited-time offers, or bundled product packages to provide a compelling reason for customers to buy during historically slower months.
# 15. **Engaging Seasonal Campaigns:** Develop unique marketing campaigns that are tied to specific holidays, events, or themes relevant to those months, creating excitement and urgency.
# 16. **Enhance Loyalty Programs:** Actively promote and reward our customer loyalty program to encourage repeat purchases and strengthen customer retention, particularly when overall sales naturally tend to be lower.
# 17. **Data-Driven Feedback:** Proactively gather customer feedback during slower periods. Understanding why customers might be purchasing less can help us adapt our offerings and messaging.
# 18. **Focused Digital Outreach:** Consider increasing investment in highly targeted digital advertising campaigns during these quieter times to maximize visibility and drive traffic to our products.
# 19. **Consider New Launches:** Strategically time the launch of new products or services to precede or coincide with historically slower months. A fresh offering can generate new buzz and revenue streams.
# 20. **Further Granular Analysis:** While this monthly overview is valuable, to pinpoint "less sold products and categories" specifically, we would need to dive deeper into our transaction data, breaking down these monthly totals by individual product lines, categories, or customer segments. This would allow for much more precise and effective marketing interventions.

# %%
os.makedirs("reports", exist_ok=True)
with open("reports/insight_report.txt", "w") as f:
    f.write(explanation)

# %%
with open("reports/insight_report.txt", "w") as f:
    f.write(explanation)

plt.savefig('output_plot.png')
print("Report saved!")
# Out:
# Report saved!

# %%
summary_text = "This is an automatically generated insight report."

images = ["output_plot.png"]

pdf_path = report_gen.generate_report(
    title="AI Generated Data Analysis Report",
    summary=summary_text,
    images=images
)

pdf_path
# Out:
# 'report_20251201_192439.pdf'

# %%
summary_text = explanation  # from explanation_agent

# %%
def generate_full_report(user_query):
    # 1. Generate code
    raw = code_gen.generate(user_query, df)
    cleaned = clean_code(raw)
    code = fix_seaborn_palette(cleaned)

    # 2. Execute code
    local_env = {"df": df, "plt": plt, "sns": sns, "pd": pd, "np": np}
    
    # remove old image
    if os.path.exists("output_plot.png"):
        os.remove("output_plot.png")

    exec_output = capture_output(code, local_env)

    # Auto debug
    if "ERROR" in exec_output:
        repaired = auto_debug_code(code, exec_output)
        repaired = clean_code(repaired)
        code = repaired
        exec_output = capture_output(code, local_env)

    # 3. Verify the plot
    print("Plot Exists:", os.path.exists("output_plot.png"))
    
    if not os.path.exists("output_plot.png"):
        raise Exception("The plot was not created, so report cannot be generated.")
    
    print("Plot file size:", os.path.getsize("output_plot.png"))

    # 4. Explanation
    python_summary = exec_output[:500]
    explanation = exp_agent.explain(user_query, python_summary)

    # 5. Generate report
    report_path = report_gen.generate_report(
        title=f"Report: {user_query}",
        summary=explanation,
        images=["output_plot.png"]
    )

    return explanation, report_path

# %%
summary, report_file = generate_full_report("Show total revenue per month")
summary, report_file
# Out:
# Plot Exists: True
# Plot file size: 88174
# ('Here\'s a breakdown of our revenue performance, month by month, with some initial thoughts and strategies:\n\n### Monthly Revenue Performance Overview\n\n*   **Strong Start to 2023:** We kicked off 2023 with our highest revenue month in January, bringing in over a billion dollars. This was an exceptionally strong performance.\n*   **Mid-Year Peak:** June also showed excellent performance, standing out as our second-highest revenue month for 2023, nearing 880 million dollars.\n*   **Consistent Highs:** Other strong months throughout 2023 included March, April, August, October, and December, all showing revenues well above 750 million dollars.\n*   **The Lowest Point of 2023:** September recorded the lowest revenue for the year 2023, coming in just under 600 million dollars. This represents a noticeable dip.\n*   **Fluctuating Patterns:** While there are strong months, we also see some dips, for example, a drop from January to February, and again from June to July, and then in September and November.\n*   **Overall Healthy 2023:** Despite the fluctuations, our company generated substantial revenue throughout 2023, consistently hitting hundreds of millions each month.\n*   **December\'s Strong Finish:** We ended 2023 on a high note in December, showing robust sales of over 830 million dollars, which is encouraging for year-end results.\n*   **A Puzzling Start to 2024:** The revenue for January 2024 is significantly lower than any month in 2023, and drastically down from January 2023. This difference, from over a billion dollars to just a few million, is a critical point that needs immediate investigation.\n\n### Key Insights and Marketing Strategies\n\n1.  **Understand January 2024\'s Anomaly:** The most urgent task is to investigate the dramatic drop in January 2024 revenue. This could be due to data entry issues, a change in reporting, or a sudden, severe market shift.\n2.  **Capitalize on Early Year Momentum:** January 2023\'s billion-dollar performance suggests a strong post-holiday or early-year demand. We should analyze what drove that success and try to replicate it in future early-year periods (excluding the 2024 anomaly).\n3.  **Address September\'s Dip:** September consistently appears to be a challenging month. This could be due to post-summer slowdowns or before the holiday shopping season ramps up.\n4.  **Boost Mid-Year Sales (July & November):** July and November also show relative dips compared to surrounding months. These periods could benefit from targeted campaigns.\n5.  **Seasonal Promotions for Lower Months:** For months like February, July, September, and November, consider running "mid-season sales," "back-to-school deals" (for September), or "pre-holiday specials" to stimulate demand.\n6.  **Product Bundling:** During slower months, combine less popular products with best-sellers at an attractive price point. This helps clear inventory and introduces customers to new items.\n7.  **Targeted Digital Campaigns:** Use our customer data to create highly specific online advertisements for products that aren\'t selling well in certain periods. Focus on benefits and unique selling points.\n8.  **Limited-Time Offers:** Create urgency with short-term discounts or exclusive deals on specific product categories during periods of lower overall revenue.\n9.  **Customer Loyalty Programs:** Encourage repeat purchases through special rewards or early access to new products for loyal customers, especially during quieter months.\n10. **Content Marketing:** Develop engaging content (blog posts, videos, social media campaigns) that educates customers about the value and uses of our less-sold products, sparking interest.\n11. **Review Product Placement/Visibility:** Ensure that less-sold products are easily discoverable on our website or in physical stores. Sometimes, simply improving visibility can make a big difference.\n12. **Gather Customer Feedback:** Directly ask customers why they might not be purchasing certain product ...
#  'report_20251201_192504.pdf')
